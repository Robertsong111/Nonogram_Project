# %%
import os
import json
import time
import pandas as pd
from ortools.sat.python import cp_model

# %%
# ---------------------------
# CP-SAT 求解器相关函数及回调类
# ---------------------------
class NonogramAllSolutionsCollector(cp_model.CpSolverSolutionCallback):
    """
    遍历 CP-SAT 所有解，把解保存下来。当解数达到 max_solutions 时调用 StopSearch() 停止枚举。
    """
    def __init__(self, x, max_solutions=1000):
        cp_model.CpSolverSolutionCallback.__init__(self)
        self._x = x
        self._solutions = []
        self._m = len(x)
        self._n = len(x[0]) if self._m > 0 else 0
        self._max_solutions = max_solutions

    def OnSolutionCallback(self):
        sol_matrix = []
        for i in range(self._m):
            row_vals = []
            for j in range(self._n):
                row_vals.append(self.Value(self._x[i][j]))
            sol_matrix.append(row_vals)
        self._solutions.append(sol_matrix)
        if len(self._solutions) >= self._max_solutions:
            self.StopSearch()

    def solutions(self):
        return self._solutions

# %%
def build_multi_block_cp_model(m, n, row_constraints, col_constraints):
    """
    使用 OR-Tools CP-SAT 建模多段 Nonogram 问题：
      row_constraints[i] = [r1, r2, ...] 表示第 i 行的每段黑块长度，
      col_constraints[j] = [c1, c2, ...] 表示第 j 列的每段黑块长度。
    返回 (model, x)，其中 x[i][j] 为布尔变量，表示网格 (i,j) 是否为黑格。
    """
    model = cp_model.CpModel()
    # 定义网格变量 x[i][j]
    x = []
    for i in range(m):
        row_vars = []
        for j in range(n):
            var = model.NewBoolVar(f"x_{i}_{j}")
            row_vars.append(var)
        x.append(row_vars)

    # ---------------------
    # 1) 多段行约束
    # ---------------------
    rowBlockVars = {}
    for i in range(m):
        blocks = row_constraints[i]
        if len(blocks) == 0:
            for j in range(n):
                model.Add(x[i][j] == 0)
            continue
        for b, length_b in enumerate(blocks):
            for start_col in range(n - length_b + 1):
                rowBlockVars[(i, b, start_col)] = model.NewBoolVar(f"rB_{i}_{b}_{start_col}")
        # 每段恰好选一个起始位置
        for b, length_b in enumerate(blocks):
            possible_starts = [rowBlockVars[(i, b, start_col)] for start_col in range(n - length_b + 1)]
            model.Add(sum(possible_starts) == 1)
        # 相邻段之间至少隔 1 列空
        for b in range(len(blocks) - 1):
            length_b = blocks[b]
            for start_s in range(n - length_b + 1):
                for start_t in range(n - blocks[b+1] + 1):
                    if start_t < start_s + length_b + 1:
                        model.Add(rowBlockVars[(i, b, start_s)] + rowBlockVars[(i, b+1, start_t)] <= 1)
        # 每个格子 x[i][col] 与行块变量覆盖关系
        for col in range(n):
            cover_vars = []
            for b, length_b in enumerate(blocks):
                for start_s in range(n - length_b + 1):
                    if start_s <= col < start_s + length_b:
                        cover_vars.append(rowBlockVars[(i, b, start_s)])
            if cover_vars:
                model.Add(x[i][col] <= sum(cover_vars))
                model.Add(x[i][col] >= sum(cover_vars))
            else:
                model.Add(x[i][col] == 0)

    # ---------------------
    # 2) 多段列约束
    # ---------------------
    colBlockVars = {}
    for j in range(n):
        blocks = col_constraints[j]
        if len(blocks) == 0:
            for i in range(m):
                model.Add(x[i][j] == 0)
            continue
        for b, length_b in enumerate(blocks):
            for start_row in range(m - length_b + 1):
                colBlockVars[(j, b, start_row)] = model.NewBoolVar(f"cB_{j}_{b}_{start_row}")
        for b, length_b in enumerate(blocks):
            possible_starts = [colBlockVars[(j, b, start_row)] for start_row in range(m - length_b + 1)]
            model.Add(sum(possible_starts) == 1)
        for b in range(len(blocks) - 1):
            length_b = blocks[b]
            for start_s in range(m - length_b + 1):
                for start_t in range(m - blocks[b+1] + 1):
                    if start_t < start_s + length_b + 1:
                        model.Add(colBlockVars[(j, b, start_s)] + colBlockVars[(j, b+1, start_t)] <= 1)
        for i in range(m):
            cover_vars = []
            for b, length_b in enumerate(blocks):
                for start_s in range(m - length_b + 1):
                    if start_s <= i < start_s + length_b:
                        cover_vars.append(colBlockVars[(j, b, start_s)])
            if cover_vars:
                model.Add(x[i][j] <= sum(cover_vars))
                model.Add(x[i][j] >= sum(cover_vars))
            else:
                model.Add(x[i][j] == 0)

    return model, x

# %%
# ---------------------------
# 调用 CP-SAT 求解器，批次处理 JSON 文件
# ---------------------------
def find_all_solutions_cp(m, n, row_constraints, col_constraints, time_limit=10.0, max_solutions=1000):
    """
    调用 build_multi_block_cp_model 构建多段 Nonogram 模型，并使用 CP-SAT 枚举解。
    参数:
      time_limit: 单个谜题求解时间上限（秒）
      max_solutions: 达到此解数后停止搜索
    返回：解的列表（每个解为 m×n 的 0/1 矩阵）
    """
    model, x = build_multi_block_cp_model(m, n, row_constraints, col_constraints)
    solver = cp_model.CpSolver()
    solver.parameters.max_time_in_seconds = time_limit
    collector = NonogramAllSolutionsCollector(x, max_solutions=max_solutions)
    status = solver.SearchForAllSolutions(model, collector)
    if status not in (cp_model.FEASIBLE, cp_model.OPTIMAL):
        print("No solution found or the model is infeasible.")
        return []
    return collector.solutions()

# %%
# ---------------------------
# 批量处理 JSON 文件并记录结果（使用 CP-SAT 求解器）
# ---------------------------
def process_puzzle_file(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# %%
def solve_puzzle(puzzle, time_limit=10.0, max_solutions=1000):
    row_hints = puzzle.get("row_hints", puzzle.get("row_constraints"))
    col_hints = puzzle.get("col_hints", puzzle.get("col_constraints"))
    m = len(row_hints)
    n = len(col_hints)
    start = time.time()
    sols = find_all_solutions_cp(m, n, row_hints, col_hints, time_limit, max_solutions)
    end = time.time()
    return end - start, len(sols)

# %%
def process_and_solve(file_path, time_limit=10.0, max_solutions=1000):
    try:
        puzzle = process_puzzle_file(file_path)
    except Exception as e:
        return {"puzzle_id": os.path.basename(file_path), "error": f"读取文件出错: {e}"}
    
    pid = puzzle.get("id", os.path.basename(file_path))
    label = puzzle.get("label", None)
    try:
        solve_time, num_sol = solve_puzzle(puzzle, time_limit, max_solutions)
    except Exception as e:
        return {"puzzle_id": pid, "error": f"求解过程中出错: {e}"}
    return {
        "puzzle_id": pid,
        "label": label,
        "row_hints": str(puzzle.get("row_hints", puzzle.get("row_constraints"))),
        "col_hints": str(puzzle.get("col_hints", puzzle.get("col_constraints"))),
        "num_solutions": num_sol,
        "solving_time_sec": solve_time
    }

# %%
def main():
    folder = "./mnist_nonograms"  # 存放谜题 JSON 的文件夹
    files = [os.path.join(folder, f) for f in os.listdir(folder) if f.lower().endswith(".json")]
    total_files = len(files)
    print(f"总共有 {total_files} 个谜题文件。")

    # 对前 10 个谜题采样估计平均求解时间
    sample_size = min(10, total_files)
    sample_times = []
    for file in files[:sample_size]:
        try:
            puzzle = process_puzzle_file(file)
            t, _ = solve_puzzle(puzzle, time_limit=10.0, max_solutions=1000)
            sample_times.append(t)
        except Exception as e:
            print(f"采样文件 {file} 出错: {e}")
    avg_time = sum(sample_times)/sample_size if sample_size > 0 else 0
    estimated_total_time = avg_time * total_files
    print(f"基于前 {sample_size} 个谜题的平均求解时间约为 {avg_time:.4f} 秒，预计全部求解时间约为 {estimated_total_time/60:.2f} 分钟。")

    records = []
    for file in files:
        try:
            record = process_and_solve(file, 10.0, 1000)
        except Exception as e:
            print(f"文件 {file} 处理出错: {e}")
            continue
        if "error" in record:
            print(f"文件 {record['puzzle_id']} 出错: {record['error']}")
        else:
            print(f"已处理谜题 {record['puzzle_id']}: {record['num_solutions']} 解, 用时 {record['solving_time_sec']:.4f} 秒")
        records.append(record)
    
    df = pd.DataFrame(records)
    output_file = "cp_sat_solver_results_seq.csv"
    df.to_csv(output_file, index=False)
    print(f"所有结果已保存至 {output_file}")

# %%
if __name__ == "__main__":
    main()
# Out:
# 总共有 1000 个谜题文件。
# 基于前 10 个谜题的平均求解时间约为 0.0716 秒，预计全部求解时间约为 1.19 分钟。
# 已处理谜题 0: 2 解, 用时 0.1128 秒
# 已处理谜题 1: 2 解, 用时 0.1570 秒
# 已处理谜题 10: 1 解, 用时 0.0526 秒
# 已处理谜题 100: 1 解, 用时 0.0748 秒
# 已处理谜题 101: 6 解, 用时 0.0805 秒
# 已处理谜题 102: 1 解, 用时 0.0334 秒
# 已处理谜题 103: 18 解, 用时 0.1135 秒
# 已处理谜题 104: 3 解, 用时 0.0294 秒
# 已处理谜题 105: 1 解, 用时 0.0618 秒
# 已处理谜题 106: 2 解, 用时 0.1131 秒
# 已处理谜题 107: 1 解, 用时 0.1071 秒
# 已处理谜题 108: 2 解, 用时 0.1428 秒
# 已处理谜题 109: 1 解, 用时 0.0726 秒
# 已处理谜题 11: 20 解, 用时 0.0953 秒
# 已处理谜题 110: 1 解, 用时 0.1487 秒
# 已处理谜题 111: 1 解, 用时 0.1638 秒
# 已处理谜题 112: 1 解, 用时 0.0510 秒
# 已处理谜题 113: 1 解, 用时 0.0565 秒
# 已处理谜题 114: 1 解, 用时 0.1540 秒
# 已处理谜题 115: 3 解, 用时 0.0691 秒
# 已处理谜题 116: 1 解, 用时 0.0782 秒
# 已处理谜题 117: 1 解, 用时 0.1198 秒
# 已处理谜题 118: 9 解, 用时 0.1550 秒
# 已处理谜题 119: 1 解, 用时 0.1612 秒
# 已处理谜题 12: 1 解, 用时 0.0964 秒
# 已处理谜题 120: 1 解, 用时 0.1290 秒
# 已处理谜题 121: 1 解, 用时 0.1236 秒
# 已处理谜题 122: 1 解, 用时 0.1234 秒
# 已处理谜题 123: 2 解, 用时 0.1120 秒
# 已处理谜题 124: 1 解, 用时 0.0422 秒
# 已处理谜题 125: 1 解, 用时 0.0980 秒
# 已处理谜题 126: 1 解, 用时 0.0773 秒
# 已处理谜题 127: 6 解, 用时 0.1011 秒
# 已处理谜题 128: 1 解, 用时 0.0556 秒
# 已处理谜题 129: 1 解, 用时 0.1268 秒
# 已处理谜题 13: 2 解, 用时 0.1513 秒
# 已处理谜题 130: 1 解, 用时 0.1061 秒
# 已处理谜题 131: 1 解, 用时 0.1232 秒
# 已处理谜题 132: 1 解, 用时 0.0452 秒
# 已处理谜题 133: 1 解, 用时 0.1172 秒
# 已处理谜题 134: 3 解, 用时 0.0566 秒
# 已处理谜题 135: 2 解, 用时 0.1190 秒
# 已处理谜题 136: 1 解, 用时 0.1294 秒
# 已处理谜题 137: 2 解, 用时 0.0987 秒
# 已处理谜题 138: 1 解, 用时 0.1277 秒
# 已处理谜题 139: 1 解, 用时 0.1176 秒
# 已处理谜题 14: 2 解, 用时 0.0259 秒
# 已处理谜题 140: 72 解, 用时 0.2885 秒
# 已处理谜题 141: 8 解, 用时 0.0917 秒
# 已处理谜题 142: 2 解, 用时 0.1244 秒
# 已处理谜题 143: 1 解, 用时 0.0836 秒
# 已处理谜题 144: 27 解, 用时 0.1710 秒
# 已处理谜题 145: 6 解, 用时 0.1304 秒
# 已处理谜题 146: 3 解, 用时 0.1027 秒
# 已处理谜题 147: 1 解, 用时 0.0785 秒
# 已处理谜题 148: 4 解, 用时 0.0992 秒
# 已处理谜题 149: 1 解, 用时 0.1605 秒
# 已处理谜题 15: 2 解, 用时 0.1274 秒
# 已处理谜题 150: 3 解, 用时 0.1290 秒
# 已处理谜题 151: 5 解, 用时 0.1246 秒
# 已处理谜题 152: 2 解, 用时 0.0434 秒
# 已处理谜题 153: 2 解, 用时 0.0818 秒
# 已处理谜题 154: 1 解, 用时 0.0915 秒
# 已处理谜题 155: 1 解, 用时 0.1331 秒
# 已处理谜题 156: 1 解, 用时 0.1356 秒
# 已处理谜题 157: 1 解, 用时 0.1157 秒
# 已处理谜题 158: 1 解, 用时 0.0789 秒
# 已处理谜题 159: 1 解, 用时 0.1172 秒
# 已处理谜题 16: 1 解, 用时 0.1681 秒
# 已处理谜题 160: 3 解, 用时 0.1573 秒
# 已处理谜题 161: 1 解, 用时 0.1632 秒
# 已处理谜题 162: 2 解, 用时 0.1119 秒
# 已处理谜题 163: 2 解, 用时 0.0717 秒
# 已处理谜题 164: 1 解, 用时 0.0636 秒
# 已处理谜题 165: 1 解, 用时 0.1510 秒
# 已处理谜题 166: 1 解, 用时 0.0901 秒
# 已处理谜题 167: 1 解, 用时 0.1496 秒
# 已处理谜题 168: 1 解, 用时 0.0949 秒
# 已处理谜题 169: 1 解, 用时 0.1322 秒
# 已处理谜题 17: 1 解, 用时 0.1200 秒
# 已处理谜题 170: 3 解, 用时 0.1103 秒
# 已处理谜题 171: 1 解, 用时 0.0881 秒
# 已处理谜题 172: 4 解, 用时 0.1163 秒
# 已处理谜题 173: 1 解, 用时 0.0627 秒
# 已处理谜题 174: 1 解, 用时 0.0409 秒
# 已处理谜题 175: 1 解, 用时 0.0727 秒
# 已处理谜题 176: 1 解, 用时 0.0560 秒
# 已处理谜题 177: 2 解, 用时 0.0661 秒
# 已处理谜题 178: 2 解, 用时 0.1793 秒
# 已处理谜题 179: 2 解, 用时 0.1787 秒
# 已处理谜题 18: 27 解, 用时 0.1268 秒
# 已处理谜题 180: 2 解, 用时 0.0871 秒
# 已处理谜题 181: 1 解, 用时 0.1330 秒
# 已处理谜题 182: 1 解, 用时 0.1359 秒
# 已处理谜题 183: 1 解, 用时 0.1145 秒
# 已处理谜题 184: 1 解, 用时 0.0474 秒
# 已处理谜题 185: 1 解, 用时 0.0966 秒
# 已处理谜题 186: 1 解, 用时 0.1406 秒
# 已处理谜题 187: 1 解, 用时 0.1437 秒
# 已处理谜题 188: 1 解, 用时 0.1471 秒
# 已处理谜题 189: 1 解, 用时 0.1550 秒
# 已处理谜题 19: 6 解, 用时 0.1447 秒
# 已处理谜题 190: 1 解, 用时 0.1535 秒
# 已处理谜题 191: 43 解, 用时 0.1937 秒
# 已处理谜题 192: 1 解, 用时 0.1288 秒
# 已处理谜题 193: 2 解, 用时 0.1180 秒
# 已处理谜题 194: 1 解, 用时 0.0827 秒
# 已处理谜题 195: 6 解, 用时 0.0940 秒
# 已处理谜题 196: 1 解, 用时 0.0804 秒
# 已处理谜题 197: 15 解, 用时 0.1828 秒
# 已处理谜题 198: 2 解, 用时 0.1205 秒
# 已处理谜题 199: 1 解, 用时 0.1683 秒
# 已处理谜题 2: 1 解, 用时 0.0682 秒
# 已处理谜题 20: 4 解, 用时 0.0675 秒
# 已处理谜题 200: 1 解, 用时 0.0571 秒
# 已处理谜题 201: 1 解, 用时 0.0576 秒
# 已处理谜题 202: 21 解, 用时 0.2210 秒
# 已处理谜题 203: 1 解, 用时 0.1263 秒
# 已处理谜题 204: 1 解, 用时 0.0816 秒
# 已处理谜题 205: 1 解, 用时 0.0606 秒
# 已处理谜题 206: 1 解, 用时 0.2177 秒
# 已处理谜题 207: 1 解, 用时 0.1054 秒
# 已处理谜题 208: 1 解, 用时 0.0559 秒
# 已处理谜题 209: 1 解, 用时 0.1552 秒
# 已处理谜题 21: 1 解, 用时 0.1793 秒
# 已处理谜题 210: 208 解, 用时 0.4652 秒
# 已处理谜题 211: 1 解, 用时 0.0683 秒
# 已处理谜题 212: 2 解, 用时 0.0872 秒
# 已处理谜题 213: 1 解, 用时 0.1880 秒
# 已处理谜题 214: 1 解, 用时 0.0807 秒
# 已处理谜题 215: 2 解, 用时 0.1981 秒
# 已处理谜题 216: 1 解, 用时 0.1354 秒
# 已处理谜题 217: 1 解, 用时 0.0929 秒
# 已处理谜题 218: 2 解, 用时 0.2109 秒
# 已处理谜题 219: 12 解, 用时 0.1641 秒
# 已处理谜题 22: 12 解, 用时 0.1748 秒
# 已处理谜题 220: 1 解, 用时 0.1799 秒
# 已处理谜题 221: 1 解, 用时 0.1678 秒
# 已处理谜题 222: 1 解, 用时 0.1425 秒
# 已处理谜题 223: 1 解, 用时 0.1311 秒
# 已处理谜题 224: 4 解, 用时 0.1912 秒
# 已处理谜题 225: 1 解, 用时 0.1686 秒
# 已处理谜题 226: 1 解, 用时 0.0989 秒
# 已处理谜题 227: 3 解, 用时 0.1125 秒
# 已处理谜题 228: 36 解, 用时 0.1947 秒
# 已处理谜题 229: 1 解, 用时 0.2256 秒
# 已处理谜题 23: 1 解, 用时 0.0656 秒
# 已处理谜题 230: 1 解, 用时 0.1181 秒
# 已处理谜题 231: 1 解, 用时 0.0462 秒
# 已处理谜题 232: 6 解, 用时 0.0794 秒
# 已处理谜题 233: 1 解, 用时 0.1404 秒
# 已处理谜题 234: 1 解, 用时 0.2444 秒
# 已处理谜题 235: 1 解, 用时 0.1352 秒
# 已处理谜题 236: 1 解, 用时 0.1363 秒
# 已处理谜题 237: 1 解, 用时 0.1489 秒
# 已处理谜题 238: 1 解, 用时 0.1919 秒
# 已处理谜题 239: 4 解, 用时 0.1448 秒
# 已处理谜题 24: 1 解, 用时 0.1015 秒
# 已处理谜题 240: 1 解, 用时 0.1090 秒
# 已处理谜题 241: 4 解, 用时 0.1275 秒
# 已处理谜题 242: 1 解, 用时 0.2012 秒
# 已处理谜题 243: 1 解, 用时 0.1324 秒
# 已处理谜题 244: 1 解, 用时 0.1637 秒
# 已处理谜题 245: 1 解, 用时 0.1254 秒
# 已处理谜题 246: 4 解, 用时 0.2021 秒
# 已处理谜题 247: 2 解, 用时 0.1368 秒
# 已处理谜题 248: 1 解, 用时 0.0457 秒
# 已处理谜题 249: 1 解, 用时 0.2398 秒
# 已处理谜题 25: 2 解, 用时 0.2214 秒
# 已处理谜题 250: 3 解, 用时 0.1486 秒
# 已处理谜题 251: 1 解, 用时 0.0728 秒
# 已处理谜题 252: 1 解, 用时 0.1039 秒
# 已处理谜题 253: 1 解, 用时 0.1899 秒
# 已处理谜题 254: 10 解, 用时 0.2307 秒
# 已处理谜题 255: 1 解, 用时 0.1554 秒
# 已处理谜题 256: 2 解, 用时 0.0933 秒
# 已处理谜题 257: 1 解, 用时 0.1226 秒
# 已处理谜题 258: 1 解, 用时 0.0845 秒
# 已处理谜题 259: 1 解, 用时 0.1261 秒
# 已处理谜题 26: 2 解, 用时 0.0938 秒
# 已处理谜题 260: 2 解, 用时 0.1576 秒
# 已处理谜题 261: 6 解, 用时 0.1108 秒
# 已处理谜题 262: 2 解, 用时 0.1057 秒
# 已处理谜题 263: 1 解, 用时 0.1140 秒
# 已处理谜题 264: 3 解, 用时 0.1444 秒
# 已处理谜题 265: 1 解, 用时 0.1989 秒
# 已处理谜题 266: 85 解, 用时 0.3205 秒
# 已处理谜题 267: 1 解, 用时 0.0958 秒
# 已处理谜题 268: 1 解, 用时 0.1113 秒
# 已处理谜题 269: 1 解, 用时 0.0502 秒
# 已处理谜题 27: 1 解, 用时 0.1612 秒
# 已处理谜题 270: 2 解, 用时 0.0652 秒
# 已处理谜题 271: 1 解, 用时 0.0845 秒
# 已处理谜题 272: 4 解, 用时 0.1143 秒
# 已处理谜题 273: 4 解, 用时 0.1197 秒
# 已处理谜题 274: 2 解, 用时 0.0887 秒
# 已处理谜题 275: 1 解, 用时 0.0852 秒
# 已处理谜题 276: 1 解, 用时 0.0327 秒
# 已处理谜题 277: 2 解, 用时 0.1582 秒
# 已处理谜题 278: 1 解, 用时 0.1496 秒
# 已处理谜题 279: 1 解, 用时 0.2244 秒
# 已处理谜题 28: 1 解, 用时 0.0956 秒
# 已处理谜题 280: 1 解, 用时 0.1711 秒
# 已处理谜题 281: 2 解, 用时 0.1127 秒
# 已处理谜题 282: 1 解, 用时 0.1061 秒
# 已处理谜题 283: 1 解, 用时 0.1383 秒
# 已处理谜题 284: 2 解, 用时 0.2256 秒
# 已处理谜题 285: 1 解, 用时 0.0818 秒
# 已处理谜题 286: 1 解, 用时 0.0680 秒
# 已处理谜题 287: 13 解, 用时 0.1248 秒
# 已处理谜题 288: 1 解, 用时 0.0580 秒
# 已处理谜题 289: 3 解, 用时 0.0943 秒
# 已处理谜题 29: 1 解, 用时 0.1293 秒
# 已处理谜题 290: 1 解, 用时 0.0468 秒
# 已处理谜题 291: 2 解, 用时 0.0789 秒
# 已处理谜题 292: 2 解, 用时 0.1098 秒
# 已处理谜题 293: 1 解, 用时 0.1304 秒
# 已处理谜题 294: 1 解, 用时 0.0885 秒
# 已处理谜题 295: 1 解, 用时 0.1583 秒
# 已处理谜题 296: 2 解, 用时 0.1465 秒
# 已处理谜题 297: 73 解, 用时 0.3111 秒
# 已处理谜题 298: 1 解, 用时 0.1141 秒
# 已处理谜题 299: 1 解, 用时 0.1406 秒
# 已处理谜题 3: 2 解, 用时 0.0340 秒
# 已处理谜题 30: 1 解, 用时 0.1442 秒
# 已处理谜题 300: 1 解, 用时 0.0943 秒
# 已处理谜题 301: 1 解, 用时 0.1335 秒
# 已处理谜题 302: 1 解, 用时 0.0798 秒
# 已处理谜题 303: 1 解, 用时 0.1756 秒
# 已处理谜题 304: 1 解, 用时 0.0808 秒
# 已处理谜题 305: 1 解, 用时 0.0931 秒
# 已处理谜题 306: 6 解, 用时 0.1375 秒
# 已处理谜题 307: 2 解, 用时 0.0812 秒
# 已处理谜题 308: 1 解, 用时 0.1213 秒
# 已处理谜题 309: 7 解, 用时 0.0625 秒
# 已处理谜题 31: 1 解, 用时 0.1464 秒
# 已处理谜题 310: 1 解, 用时 0.0298 秒
# 已处理谜题 311: 1 解, 用时 0.1065 秒
# 已处理谜题 312: 1 解, 用时 0.1181 秒
# 已处理谜题 313: 1 解, 用时 0.0971 秒
# 已处理谜题 314: 3 解, 用时 0.0871 秒
# 已处理谜题 315: 1 解, 用时 0.0320 秒
# 已处理谜题 316: 21 解, 用时 0.1053 秒
# 已处理谜题 317: 1 解, 用时 0.1207 秒
# 已处理谜题 318: 1 解, 用时 0.1416 秒
# 已处理谜题 319: 6 解, 用时 0.1096 秒
# 已处理谜题 32: 6 解, 用时 0.0924 秒
# 已处理谜题 320: 1 解, 用时 0.1310 秒
# 已处理谜题 321: 2 解, 用时 0.0971 秒
# 已处理谜题 322: 4 解, 用时 0.0825 秒
# 已处理谜题 323: 1 解, 用时 0.1325 秒
# 已处理谜题 324: 1 解, 用时 0.0822 秒
# 已处理谜题 325: 1 解, 用时 0.0927 秒
# 已处理谜题 326: 2 解, 用时 0.1770 秒
# 已处理谜题 327: 1 解, 用时 0.1625 秒
# 已处理谜题 328: 1 解, 用时 0.1561 秒
# 已处理谜题 329: 1 解, 用时 0.0883 秒
# 已处理谜题 33: 2 解, 用时 0.1027 秒
# 已处理谜题 330: 2 解, 用时 0.0689 秒
# 已处理谜题 331: 1 解, 用时 0.1393 秒
# 已处理谜题 332: 4 解, 用时 0.1382 秒
# 已处理谜题 333: 1 解, 用时 0.1663 秒
# 已处理谜题 334: 1 解, 用时 0.1171 秒
# 已处理谜题 335: 21 解, 用时 0.1493 秒
# 已处理谜题 336: 1 解, 用时 0.0895 秒
# 已处理谜题 337: 1 解, 用时 0.1180 秒
# 已处理谜题 338: 18 解, 用时 0.1371 秒
# 已处理谜题 339: 1 解, 用时 0.1795 秒
# 已处理谜题 34: 1 解, 用时 0.1136 秒
# 已处理谜题 340: 1 解, 用时 0.0841 秒
# 已处理谜题 341: 2 解, 用时 0.1614 秒
# 已处理谜题 342: 2 解, 用时 0.0742 秒
# 已处理谜题 343: 5 解, 用时 0.1024 秒
# 已处理谜题 344: 2 解, 用时 0.0867 秒
# 已处理谜题 345: 1 解, 用时 0.0488 秒
# 已处理谜题 346: 4 解, 用时 0.1036 秒
# 已处理谜题 347: 1 解, 用时 0.1678 秒
# 已处理谜题 348: 1 解, 用时 0.1280 秒
# 已处理谜题 349: 1 解, 用时 0.1115 秒
# 已处理谜题 35: 19 解, 用时 0.1502 秒
# 已处理谜题 350: 2 解, 用时 0.1050 秒
# 已处理谜题 351: 2 解, 用时 0.0365 秒
# 已处理谜题 352: 1 解, 用时 0.1283 秒
# 已处理谜题 353: 2 解, 用时 0.0620 秒
# 已处理谜题 354: 2 解, 用时 0.0737 秒
# 已处理谜题 355: 1 解, 用时 0.0345 秒
# 已处理谜题 356: 1 解, 用时 0.0631 秒
# 已处理谜题 357: 1 解, 用时 0.0637 秒
# 已处理谜题 358: 2 解, 用时 0.0575 秒
# 已处理谜题 359: 1 解, 用时 0.1595 秒
# 已处理谜题 36: 1 解, 用时 0.0711 秒
# 已处理谜题 360: 1 解, 用时 0.0922 秒
# 已处理谜题 361: 1 解, 用时 0.1558 秒
# 已处理谜题 362: 1 解, 用时 0.1139 秒
# 已处理谜题 363: 3 解, 用时 0.0645 秒
# 已处理谜题 364: 4 解, 用时 0.1326 秒
# 已处理谜题 365: 2 解, 用时 0.1297 秒
# 已处理谜题 366: 3 解, 用时 0.0585 秒
# 已处理谜题 367: 1 解, 用时 0.1268 秒
# 已处理谜题 368: 2 解, 用时 0.1482 秒
# 已处理谜题 369: 1 解, 用时 0.0912 秒
# 已处理谜题 37: 1 解, 用时 0.0906 秒
# 已处理谜题 370: 1 解, 用时 0.0402 秒
# 已处理谜题 371: 1 解, 用时 0.0825 秒
# 已处理谜题 372: 1 解, 用时 0.0854 秒
# 已处理谜题 373: 1 解, 用时 0.0476 秒
# 已处理谜题 374: 1 解, 用时 0.0861 秒
# 已处理谜题 375: 1 解, 用时 0.1362 秒
# 已处理谜题 376: 2 解, 用时 0.1445 秒
# 已处理谜题 377: 1 解, 用时 0.1436 秒
# 已处理谜题 378: 2 解, 用时 0.1108 秒
# 已处理谜题 379: 9 解, 用时 0.0861 秒
# 已处理谜题 38: 1 解, 用时 0.0916 秒
# 已处理谜题 380: 1 解, 用时 0.1546 秒
# 已处理谜题 381: 1 解, 用时 0.1247 秒
# 已处理谜题 382: 1 解, 用时 0.0405 秒
# 已处理谜题 383: 1 解, 用时 0.1462 秒
# 已处理谜题 384: 3 解, 用时 0.0847 秒
# 已处理谜题 385: 1 解, 用时 0.1373 秒
# 已处理谜题 386: 1 解, 用时 0.1620 秒
# 已处理谜题 387: 2 解, 用时 0.1252 秒
# 已处理谜题 388: 3 解, 用时 0.0629 秒
# 已处理谜题 389: 3 解, 用时 0.0926 秒
# 已处理谜题 39: 1 解, 用时 0.1025 秒
# 已处理谜题 390: 2 解, 用时 0.1436 秒
# 已处理谜题 391: 1 解, 用时 0.1608 秒
# 已处理谜题 392: 1 解, 用时 0.1578 秒
# 已处理谜题 393: 1 解, 用时 0.1405 秒
# 已处理谜题 394: 3 解, 用时 0.0662 秒
# 已处理谜题 395: 1 解, 用时 0.1476 秒
# 已处理谜题 396: 54 解, 用时 0.2276 秒
# 已处理谜题 397: 1 解, 用时 0.0651 秒
# 已处理谜题 398: 1 解, 用时 0.0666 秒
# 已处理谜题 399: 1 解, 用时 0.1196 秒
# 已处理谜题 4: 1 解, 用时 0.1047 秒
# 已处理谜题 40: 2 解, 用时 0.0469 秒
# 已处理谜题 400: 1 解, 用时 0.1501 秒
# 已处理谜题 401: 2 解, 用时 0.1096 秒
# 已处理谜题 402: 1 解, 用时 0.0748 秒
# 已处理谜题 403: 1 解, 用时 0.1338 秒
# 已处理谜题 404: 3 解, 用时 0.2042 秒
# 已处理谜题 405: 2 解, 用时 0.1720 秒
# 已处理谜题 406: 3 解, 用时 0.0474 秒
# 已处理谜题 407: 24 解, 用时 0.1660 秒
# 已处理谜题 408: 1 解, 用时 0.0377 秒
# 已处理谜题 409: 4 解, 用时 0.1339 秒
# 已处理谜题 41: 1 解, 用时 0.2109 秒
# 已处理谜题 410: 1 解, 用时 0.1023 秒
# 已处理谜题 411: 1 解, 用时 0.0818 秒
# 已处理谜题 412: 2 解, 用时 0.0613 秒
# 已处理谜题 413: 18 解, 用时 0.0927 秒
# 已处理谜题 414: 1 解, 用时 0.1272 秒
# 已处理谜题 415: 1 解, 用时 0.1240 秒
# 已处理谜题 416: 1 解, 用时 0.0604 秒
# 已处理谜题 417: 5 解, 用时 0.1104 秒
# 已处理谜题 418: 673 解, 用时 1.1674 秒
# 已处理谜题 419: 1 解, 用时 0.1377 秒
# 已处理谜题 42: 2 解, 用时 0.0695 秒
# 已处理谜题 420: 2 解, 用时 0.1111 秒
# 已处理谜题 421: 2 解, 用时 0.1146 秒
# 已处理谜题 422: 1 解, 用时 0.0546 秒
# 已处理谜题 423: 4 解, 用时 0.1405 秒
# 已处理谜题 424: 1 解, 用时 0.0837 秒
# 已处理谜题 425: 3 解, 用时 0.1550 秒
# 已处理谜题 426: 1 解, 用时 0.0737 秒
# 已处理谜题 427: 1 解, 用时 0.1768 秒
# 已处理谜题 428: 1 解, 用时 0.1053 秒
# 已处理谜题 429: 1 解, 用时 0.1547 秒
# 已处理谜题 43: 7 解, 用时 0.1391 秒
# 已处理谜题 430: 2 解, 用时 0.1366 秒
# 已处理谜题 431: 2 解, 用时 0.1406 秒
# 已处理谜题 432: 2 解, 用时 0.1353 秒
# 已处理谜题 433: 2 解, 用时 0.1709 秒
# 已处理谜题 434: 166 解, 用时 0.4402 秒
# 已处理谜题 435: 1 解, 用时 0.2206 秒
# 已处理谜题 436: 12 解, 用时 0.1577 秒
# 已处理谜题 437: 1 解, 用时 0.0752 秒
# 已处理谜题 438: 1 解, 用时 0.0815 秒
# 已处理谜题 439: 1 解, 用时 0.1116 秒
# 已处理谜题 44: 84 解, 用时 0.3098 秒
# 已处理谜题 440: 1 解, 用时 0.1972 秒
# 已处理谜题 441: 4 解, 用时 0.1319 秒
# 已处理谜题 442: 2 解, 用时 0.1659 秒
# 已处理谜题 443: 1 解, 用时 0.0548 秒
# 已处理谜题 444: 1 解, 用时 0.0427 秒
# 已处理谜题 445: 2 解, 用时 0.1323 秒
# 已处理谜题 446: 1 解, 用时 0.1136 秒
# 已处理谜题 447: 1 解, 用时 0.0471 秒
# 已处理谜题 448: 1 解, 用时 0.0771 秒
# 已处理谜题 449: 1 解, 用时 0.1025 秒
# 已处理谜题 45: 1 解, 用时 0.1452 秒
# 已处理谜题 450: 1 解, 用时 0.0558 秒
# 已处理谜题 451: 1 解, 用时 0.1361 秒
# 已处理谜题 452: 2 解, 用时 0.1905 秒
# 已处理谜题 453: 1 解, 用时 0.1725 秒
# 已处理谜题 454: 1 解, 用时 0.0445 秒
# 已处理谜题 455: 1 解, 用时 0.0844 秒
# 已处理谜题 456: 3 解, 用时 0.1291 秒
# 已处理谜题 457: 1 解, 用时 0.1379 秒
# 已处理谜题 458: 1 解, 用时 0.1867 秒
# 已处理谜题 459: 3 解, 用时 0.1871 秒
# 已处理谜题 46: 1 解, 用时 0.2512 秒
# 已处理谜题 460: 7 解, 用时 0.1825 秒
# 已处理谜题 461: 2 解, 用时 0.1395 秒
# 已处理谜题 462: 1 解, 用时 0.2097 秒
# 已处理谜题 463: 1 解, 用时 0.0704 秒
# 已处理谜题 464: 1 解, 用时 0.2159 秒
# 已处理谜题 465: 1 解, 用时 0.1839 秒
# 已处理谜题 466: 4 解, 用时 0.0554 秒
# 已处理谜题 467: 1 解, 用时 0.1281 秒
# 已处理谜题 468: 10 解, 用时 0.1726 秒
# 已处理谜题 469: 2 解, 用时 0.2064 秒
# 已处理谜题 47: 1 解, 用时 0.0999 秒
# 已处理谜题 470: 4 解, 用时 0.0983 秒
# 已处理谜题 471: 3 解, 用时 0.1802 秒
# 已处理谜题 472: 12 解, 用时 0.1358 秒
# 已处理谜题 473: 1 解, 用时 0.2209 秒
# 已处理谜题 474: 4 解, 用时 0.1282 秒
# 已处理谜题 475: 10 解, 用时 0.1246 秒
# 已处理谜题 476: 1 解, 用时 0.1813 秒
# 已处理谜题 477: 1 解, 用时 0.2033 秒
# 已处理谜题 478: 1 解, 用时 0.1062 秒
# 已处理谜题 479: 1 解, 用时 0.1863 秒
# 已处理谜题 48: 2 解, 用时 0.1550 秒
# 已处理谜题 480: 1 解, 用时 0.1168 秒
# 已处理谜题 481: 11 解, 用时 0.1555 秒
# 已处理谜题 482: 1 解, 用时 0.1618 秒
# 已处理谜题 483: 2 解, 用时 0.1594 秒
# 已处理谜题 484: 1 解, 用时 0.0568 秒
# 已处理谜题 485: 3 解, 用时 0.2035 秒
# 已处理谜题 486: 1 解, 用时 0.1755 秒
# 已处理谜题 487: 93 解, 用时 0.3063 秒
# 已处理谜题 488: 1 解, 用时 0.1706 秒
# 已处理谜题 489: 2 解, 用时 0.1726 秒
# 已处理谜题 49: 1 解, 用时 0.1289 秒
# 已处理谜题 490: 2 解, 用时 0.1772 秒
# 已处理谜题 491: 1 解, 用时 0.0423 秒
# 已处理谜题 492: 1 解, 用时 0.0508 秒
# 已处理谜题 493: 1 解, 用时 0.1072 秒
# 已处理谜题 494: 1 解, 用时 0.1521 秒
# 已处理谜题 495: 1 解, 用时 0.1252 秒
# 已处理谜题 496: 1 解, 用时 0.1345 秒
# 已处理谜题 497: 2 解, 用时 0.1087 秒
# 已处理谜题 498: 12 解, 用时 0.1348 秒
# 已处理谜题 499: 1 解, 用时 0.1677 秒
# 已处理谜题 5: 1 解, 用时 0.1361 秒
# 已处理谜题 50: 6 解, 用时 0.1559 秒
# 已处理谜题 500: 13 解, 用时 0.1366 秒
# 已处理谜题 501: 1 解, 用时 0.0899 秒
# 已处理谜题 502: 3 解, 用时 0.0626 秒
# 已处理谜题 503: 7 解, 用时 0.1837 秒
# 已处理谜题 504: 1 解, 用时 0.1453 秒
# 已处理谜题 505: 1 解, 用时 0.1159 秒
# 已处理谜题 506: 14 解, 用时 0.1941 秒
# 已处理谜题 507: 1 解, 用时 0.0651 秒
# 已处理谜题 508: 1 解, 用时 0.0616 秒
# 已处理谜题 509: 3 解, 用时 0.1742 秒
# 已处理谜题 51: 1 解, 用时 0.1029 秒
# 已处理谜题 510: 1 解, 用时 0.0290 秒
# 已处理谜题 511: 12 解, 用时 0.1225 秒
# 已处理谜题 512: 1 解, 用时 0.1676 秒
# 已处理谜题 513: 24 解, 用时 0.1365 秒
# 已处理谜题 514: 2 解, 用时 0.0688 秒
# 已处理谜题 515: 1 解, 用时 0.1151 秒
# 已处理谜题 516: 1 解, 用时 0.1386 秒
# 已处理谜题 517: 2 解, 用时 0.1151 秒
# 已处理谜题 518: 5 解, 用时 0.0824 秒
# 已处理谜题 519: 1 解, 用时 0.1663 秒
# 已处理谜题 52: 1 解, 用时 0.0739 秒
# 已处理谜题 520: 1 解, 用时 0.0946 秒
# 已处理谜题 521: 1 解, 用时 0.1289 秒
# 已处理谜题 522: 1 解, 用时 0.0835 秒
# 已处理谜题 523: 2 解, 用时 0.1035 秒
# 已处理谜题 524: 2 解, 用时 0.1774 秒
# 已处理谜题 525: 1 解, 用时 0.1220 秒
# 已处理谜题 526: 1 解, 用时 0.1712 秒
# 已处理谜题 527: 1 解, 用时 0.1445 秒
# 已处理谜题 528: 1 解, 用时 0.1427 秒
# 已处理谜题 529: 1 解, 用时 0.0857 秒
# 已处理谜题 53: 2 解, 用时 0.0800 秒
# 已处理谜题 530: 7 解, 用时 0.1158 秒
# 已处理谜题 531: 15 解, 用时 0.0985 秒
# 已处理谜题 532: 1 解, 用时 0.1195 秒
# 已处理谜题 533: 16 解, 用时 0.0938 秒
# 已处理谜题 534: 1 解, 用时 0.1556 秒
# 已处理谜题 535: 1 解, 用时 0.0354 秒
# 已处理谜题 536: 2 解, 用时 0.0806 秒
# 已处理谜题 537: 2 解, 用时 0.0615 秒
# 已处理谜题 538: 19 解, 用时 0.0488 秒
# 已处理谜题 539: 1 解, 用时 0.1486 秒
# 已处理谜题 54: 2 解, 用时 0.1665 秒
# 已处理谜题 540: 118 解, 用时 0.2630 秒
# 已处理谜题 541: 2 解, 用时 0.1178 秒
# 已处理谜题 542: 1 解, 用时 0.1303 秒
# 已处理谜题 543: 21 解, 用时 0.1606 秒
# 已处理谜题 544: 1 解, 用时 0.1755 秒
# 已处理谜题 545: 5 解, 用时 0.1661 秒
# 已处理谜题 546: 4 解, 用时 0.1514 秒
# 已处理谜题 547: 2 解, 用时 0.1051 秒
# 已处理谜题 548: 1 解, 用时 0.1735 秒
# 已处理谜题 549: 1 解, 用时 0.1385 秒
# 已处理谜题 55: 1 解, 用时 0.1337 秒
# 已处理谜题 550: 1 解, 用时 0.0717 秒
# 已处理谜题 551: 2 解, 用时 0.1444 秒
# 已处理谜题 552: 1 解, 用时 0.0446 秒
# 已处理谜题 553: 3 解, 用时 0.0698 秒
# 已处理谜题 554: 1 解, 用时 0.1151 秒
# 已处理谜题 555: 1 解, 用时 0.0842 秒
# 已处理谜题 556: 1 解, 用时 0.0561 秒
# 已处理谜题 557: 1 解, 用时 0.1484 秒
# 已处理谜题 558: 4 解, 用时 0.0710 秒
# 已处理谜题 559: 1 解, 用时 0.1837 秒
# 已处理谜题 56: 1 解, 用时 0.1602 秒
# 已处理谜题 560: 1 解, 用时 0.0981 秒
# 已处理谜题 561: 6 解, 用时 0.1714 秒
# 已处理谜题 562: 1 解, 用时 0.0569 秒
# 已处理谜题 563: 2 解, 用时 0.1249 秒
# 已处理谜题 564: 1 解, 用时 0.0893 秒
# 已处理谜题 565: 1 解, 用时 0.1212 秒
# 已处理谜题 566: 8 解, 用时 0.1275 秒
# 已处理谜题 567: 2 解, 用时 0.0887 秒
# 已处理谜题 568: 1 解, 用时 0.0871 秒
# 已处理谜题 569: 2 解, 用时 0.1163 秒
# 已处理谜题 57: 2 解, 用时 0.1167 秒
# 已处理谜题 570: 1 解, 用时 0.0941 秒
# 已处理谜题 571: 4 解, 用时 0.1428 秒
# 已处理谜题 572: 2 解, 用时 0.0524 秒
# 已处理谜题 573: 1 解, 用时 0.0559 秒
# 已处理谜题 574: 5 解, 用时 0.0830 秒
# 已处理谜题 575: 1 解, 用时 0.0854 秒
# 已处理谜题 576: 8 解, 用时 0.0742 秒
# 已处理谜题 577: 1 解, 用时 0.1611 秒
# 已处理谜题 578: 1 解, 用时 0.1185 秒
# 已处理谜题 579: 5 解, 用时 0.0760 秒
# 已处理谜题 58: 1 解, 用时 0.0599 秒
# 已处理谜题 580: 4 解, 用时 0.1396 秒
# 已处理谜题 581: 1 解, 用时 0.1521 秒
# 已处理谜题 582: 3 解, 用时 0.1727 秒
# 已处理谜题 583: 43 解, 用时 0.1922 秒
# 已处理谜题 584: 74 解, 用时 0.3162 秒
# 已处理谜题 585: 1 解, 用时 0.0665 秒
# 已处理谜题 586: 1000 解, 用时 1.6712 秒
# 已处理谜题 587: 39 解, 用时 0.1524 秒
# 已处理谜题 588: 2 解, 用时 0.0610 秒
# 已处理谜题 589: 1 解, 用时 0.0895 秒
# 已处理谜题 59: 1 解, 用时 0.0615 秒
# 已处理谜题 590: 2 解, 用时 0.1375 秒
# 已处理谜题 591: 1 解, 用时 0.1627 秒
# 已处理谜题 592: 1 解, 用时 0.0902 秒
# 已处理谜题 593: 4 解, 用时 0.0490 秒
# 已处理谜题 594: 4 解, 用时 0.1919 秒
# 已处理谜题 595: 108 解, 用时 0.3118 秒
# 已处理谜题 596: 1 解, 用时 0.1153 秒
# 已处理谜题 597: 1 解, 用时 0.1356 秒
# 已处理谜题 598: 1 解, 用时 0.1103 秒
# 已处理谜题 599: 6 解, 用时 0.0984 秒
# 已处理谜题 6: 1 解, 用时 0.0553 秒
# 已处理谜题 60: 1 解, 用时 0.1342 秒
# 已处理谜题 600: 2 解, 用时 0.0903 秒
# 已处理谜题 601: 749 解, 用时 1.4411 秒
# 已处理谜题 602: 2 解, 用时 0.3262 秒
# 已处理谜题 603: 1 解, 用时 0.0986 秒
# 已处理谜题 604: 3 解, 用时 0.0324 秒
# 已处理谜题 605: 9 解, 用时 0.1590 秒
# 已处理谜题 606: 1 解, 用时 0.0760 秒
# 已处理谜题 607: 2 解, 用时 0.1375 秒
# 已处理谜题 608: 1 解, 用时 0.0839 秒
# 已处理谜题 609: 3 解, 用时 0.0729 秒
# 已处理谜题 61: 16 解, 用时 0.1155 秒
# 已处理谜题 610: 6 解, 用时 0.0988 秒
# 已处理谜题 611: 2 解, 用时 0.0703 秒
# 已处理谜题 612: 1 解, 用时 0.1017 秒
# 已处理谜题 613: 1 解, 用时 0.1456 秒
# 已处理谜题 614: 1 解, 用时 0.0934 秒
# 已处理谜题 615: 307 解, 用时 0.8957 秒
# 已处理谜题 616: 1 解, 用时 0.0817 秒
# 已处理谜题 617: 3 解, 用时 0.1269 秒
# 已处理谜题 618: 1 解, 用时 0.0384 秒
# 已处理谜题 619: 1 解, 用时 0.1010 秒
# 已处理谜题 62: 1 解, 用时 0.1143 秒
# 已处理谜题 620: 1 解, 用时 0.1530 秒
# 已处理谜题 621: 6 解, 用时 0.2567 秒
# 已处理谜题 622: 2 解, 用时 0.1264 秒
# 已处理谜题 623: 1 解, 用时 0.1317 秒
# 已处理谜题 624: 2 解, 用时 0.1319 秒
# 已处理谜题 625: 1 解, 用时 0.1386 秒
# 已处理谜题 626: 1 解, 用时 0.1461 秒
# 已处理谜题 627: 204 解, 用时 0.6747 秒
# 已处理谜题 628: 45 解, 用时 0.2026 秒
# 已处理谜题 629: 1 解, 用时 0.1765 秒
# 已处理谜题 63: 1 解, 用时 0.1758 秒
# 已处理谜题 630: 1 解, 用时 0.0910 秒
# 已处理谜题 631: 12 解, 用时 0.2032 秒
# 已处理谜题 632: 1 解, 用时 0.1475 秒
# 已处理谜题 633: 1 解, 用时 0.1721 秒
# 已处理谜题 634: 10 解, 用时 0.1274 秒
# 已处理谜题 635: 1 解, 用时 0.1507 秒
# 已处理谜题 636: 5 解, 用时 0.0992 秒
# 已处理谜题 637: 26 解, 用时 0.1450 秒
# 已处理谜题 638: 1 解, 用时 0.0482 秒
# 已处理谜题 639: 1 解, 用时 0.1608 秒
# 已处理谜题 64: 1 解, 用时 0.1415 秒
# 已处理谜题 640: 1 解, 用时 0.0717 秒
# 已处理谜题 641: 1 解, 用时 0.1377 秒
# 已处理谜题 642: 1 解, 用时 0.1569 秒
# 已处理谜题 643: 1 解, 用时 0.1376 秒
# 已处理谜题 644: 1 解, 用时 0.0764 秒
# 已处理谜题 645: 1 解, 用时 0.1424 秒
# 已处理谜题 646: 1 解, 用时 0.0835 秒
# 已处理谜题 647: 1000 解, 用时 2.9206 秒
# 已处理谜题 648: 1 解, 用时 0.0325 秒
# 已处理谜题 649: 1 解, 用时 0.1173 秒
# 已处理谜题 65: 1 解, 用时 0.0960 秒
# 已处理谜题 650: 1 解, 用时 0.1042 秒
# 已处理谜题 651: 1 解, 用时 0.0873 秒
# 已处理谜题 652: 1 解, 用时 0.0986 秒
# 已处理谜题 653: 1 解, 用时 0.1246 秒
# 已处理谜题 654: 1 解, 用时 0.0910 秒
# 已处理谜题 655: 2 解, 用时 0.1241 秒
# 已处理谜题 656: 1 解, 用时 0.1109 秒
# 已处理谜题 657: 1 解, 用时 0.1195 秒
# 已处理谜题 658: 1 解, 用时 0.1191 秒
# 已处理谜题 659: 1 解, 用时 0.1069 秒
# 已处理谜题 66: 3 解, 用时 0.1264 秒
# 已处理谜题 660: 2 解, 用时 0.1011 秒
# 已处理谜题 661: 22 解, 用时 0.1652 秒
# 已处理谜题 662: 35 解, 用时 0.2496 秒
# 已处理谜题 663: 8 解, 用时 0.1273 秒
# 已处理谜题 664: 1 解, 用时 0.1035 秒
# 已处理谜题 665: 1 解, 用时 0.0732 秒
# 已处理谜题 666: 2 解, 用时 0.1391 秒
# 已处理谜题 667: 1 解, 用时 0.1090 秒
# 已处理谜题 668: 1 解, 用时 0.1328 秒
# 已处理谜题 669: 1 解, 用时 0.1403 秒
# 已处理谜题 67: 2 解, 用时 0.0545 秒
# 已处理谜题 670: 1 解, 用时 0.2114 秒
# 已处理谜题 671: 1 解, 用时 0.0627 秒
# 已处理谜题 672: 1 解, 用时 0.1079 秒
# 已处理谜题 673: 2 解, 用时 0.0897 秒
# 已处理谜题 674: 2 解, 用时 0.0960 秒
# 已处理谜题 675: 1 解, 用时 0.1111 秒
# 已处理谜题 676: 2 解, 用时 0.0389 秒
# 已处理谜题 677: 1 解, 用时 0.0681 秒
# 已处理谜题 678: 1 解, 用时 0.0432 秒
# 已处理谜题 679: 2 解, 用时 0.1533 秒
# 已处理谜题 68: 1000 解, 用时 1.3420 秒
# 已处理谜题 680: 2 解, 用时 0.0996 秒
# 已处理谜题 681: 1 解, 用时 0.0872 秒
# 已处理谜题 682: 1 解, 用时 0.0751 秒
# 已处理谜题 683: 1 解, 用时 0.0691 秒
# 已处理谜题 684: 1 解, 用时 0.0596 秒
# 已处理谜题 685: 2 解, 用时 0.0747 秒
# 已处理谜题 686: 2 解, 用时 0.0576 秒
# 已处理谜题 687: 1 解, 用时 0.0999 秒
# 已处理谜题 688: 1 解, 用时 0.0691 秒
# 已处理谜题 689: 1 解, 用时 0.1773 秒
# 已处理谜题 69: 1 解, 用时 0.1081 秒
# 已处理谜题 690: 4 解, 用时 0.1255 秒
# 已处理谜题 691: 2 解, 用时 0.0363 秒
# 已处理谜题 692: 1 解, 用时 0.1058 秒
# 已处理谜题 693: 1 解, 用时 0.0774 秒
# 已处理谜题 694: 1 解, 用时 0.1308 秒
# 已处理谜题 695: 1 解, 用时 0.1048 秒
# 已处理谜题 696: 2 解, 用时 0.1313 秒
# 已处理谜题 697: 1 解, 用时 0.0847 秒
# 已处理谜题 698: 2 解, 用时 0.0383 秒
# 已处理谜题 699: 1 解, 用时 0.1864 秒
# 已处理谜题 7: 1 解, 用时 0.1208 秒
# 已处理谜题 70: 1 解, 用时 0.0447 秒
# 已处理谜题 700: 30 解, 用时 0.1518 秒
# 已处理谜题 701: 1 解, 用时 0.1080 秒
# 已处理谜题 702: 1 解, 用时 0.1105 秒
# 已处理谜题 703: 1 解, 用时 0.0684 秒
# 已处理谜题 704: 3 解, 用时 0.1375 秒
# 已处理谜题 705: 1 解, 用时 0.1532 秒
# 已处理谜题 706: 1 解, 用时 0.1007 秒
# 已处理谜题 707: 2 解, 用时 0.1125 秒
# 已处理谜题 708: 1 解, 用时 0.1083 秒
# 已处理谜题 709: 1 解, 用时 0.1847 秒
# 已处理谜题 71: 19 解, 用时 0.1640 秒
# 已处理谜题 710: 1 解, 用时 0.0534 秒
# 已处理谜题 711: 2 解, 用时 0.0393 秒
# 已处理谜题 712: 1 解, 用时 0.1365 秒
# 已处理谜题 713: 1 解, 用时 0.1106 秒
# 已处理谜题 714: 4 解, 用时 0.1306 秒
# 已处理谜题 715: 1 解, 用时 0.1474 秒
# 已处理谜题 716: 1 解, 用时 0.1612 秒
# 已处理谜题 717: 1 解, 用时 0.1943 秒
# 已处理谜题 718: 1 解, 用时 0.0454 秒
# 已处理谜题 719: 1 解, 用时 0.1637 秒
# 已处理谜题 72: 1 解, 用时 0.0523 秒
# 已处理谜题 720: 1 解, 用时 0.0484 秒
# 已处理谜题 721: 1 解, 用时 0.1231 秒
# 已处理谜题 722: 2 解, 用时 0.2075 秒
# 已处理谜题 723: 1 解, 用时 0.0834 秒
# 已处理谜题 724: 1 解, 用时 0.0436 秒
# 已处理谜题 725: 1 解, 用时 0.1269 秒
# 已处理谜题 726: 3 解, 用时 0.1158 秒
# 已处理谜题 727: 1 解, 用时 0.1108 秒
# 已处理谜题 728: 23 解, 用时 0.1227 秒
# 已处理谜题 729: 1 解, 用时 0.0945 秒
# 已处理谜题 73: 2 解, 用时 0.1642 秒
# 已处理谜题 730: 1 解, 用时 0.0952 秒
# 已处理谜题 731: 1 解, 用时 0.0950 秒
# 已处理谜题 732: 1 解, 用时 0.1500 秒
# 已处理谜题 733: 1 解, 用时 0.1226 秒
# 已处理谜题 734: 1 解, 用时 0.2039 秒
# 已处理谜题 735: 1 解, 用时 0.1635 秒
# 已处理谜题 736: 13 解, 用时 0.1741 秒
# 已处理谜题 737: 1 解, 用时 0.1717 秒
# 已处理谜题 738: 1 解, 用时 0.0366 秒
# 已处理谜题 739: 4 解, 用时 0.1799 秒
# 已处理谜题 74: 1 解, 用时 0.1091 秒
# 已处理谜题 740: 4 解, 用时 0.1357 秒
# 已处理谜题 741: 4 解, 用时 0.1480 秒
# 已处理谜题 742: 4 解, 用时 0.1531 秒
# 已处理谜题 743: 1 解, 用时 0.1710 秒
# 已处理谜题 744: 1 解, 用时 0.1272 秒
# 已处理谜题 745: 1 解, 用时 0.1843 秒
# 已处理谜题 746: 2 解, 用时 0.0817 秒
# 已处理谜题 747: 1 解, 用时 0.0680 秒
# 已处理谜题 748: 1 解, 用时 0.1381 秒
# 已处理谜题 749: 1 解, 用时 0.1170 秒
# 已处理谜题 75: 1 解, 用时 0.0994 秒
# 已处理谜题 750: 6 解, 用时 0.0907 秒
# 已处理谜题 751: 1 解, 用时 0.1222 秒
# 已处理谜题 752: 1 解, 用时 0.1783 秒
# 已处理谜题 753: 1 解, 用时 0.0818 秒
# 已处理谜题 754: 5 解, 用时 0.0624 秒
# 已处理谜题 755: 1 解, 用时 0.0780 秒
# 已处理谜题 756: 1 解, 用时 0.0909 秒
# 已处理谜题 757: 1 解, 用时 0.1563 秒
# 已处理谜题 758: 1 解, 用时 0.1212 秒
# 已处理谜题 759: 1 解, 用时 0.1081 秒
# 已处理谜题 76: 1 解, 用时 0.1598 秒
# 已处理谜题 760: 12 解, 用时 0.1687 秒
# 已处理谜题 761: 1 解, 用时 0.1551 秒
# 已处理谜题 762: 2 解, 用时 0.1174 秒
# 已处理谜题 763: 2 解, 用时 0.0951 秒
# 已处理谜题 764: 1 解, 用时 0.1204 秒
# 已处理谜题 765: 1 解, 用时 0.0361 秒
# 已处理谜题 766: 1 解, 用时 0.1149 秒
# 已处理谜题 767: 1 解, 用时 0.0967 秒
# 已处理谜题 768: 2 解, 用时 0.1706 秒
# 已处理谜题 769: 1 解, 用时 0.1362 秒
# 已处理谜题 77: 1 解, 用时 0.0341 秒
# 已处理谜题 770: 36 解, 用时 0.0719 秒
# 已处理谜题 771: 2 解, 用时 0.0947 秒
# 已处理谜题 772: 1 解, 用时 0.1453 秒
# 已处理谜题 773: 1 解, 用时 0.0765 秒
# 已处理谜题 774: 1 解, 用时 0.1161 秒
# 已处理谜题 775: 35 解, 用时 0.1781 秒
# 已处理谜题 776: 1 解, 用时 0.1274 秒
# 已处理谜题 777: 1 解, 用时 0.1399 秒
# 已处理谜题 778: 2 解, 用时 0.0689 秒
# 已处理谜题 779: 1 解, 用时 0.0507 秒
# 已处理谜题 78: 1 解, 用时 0.0632 秒
# 已处理谜题 780: 1 解, 用时 0.0633 秒
# 已处理谜题 781: 1 解, 用时 0.1633 秒
# 已处理谜题 782: 6 解, 用时 0.1550 秒
# 已处理谜题 783: 1 解, 用时 0.0519 秒
# 已处理谜题 784: 2 解, 用时 0.1749 秒
# 已处理谜题 785: 2 解, 用时 0.0907 秒
# 已处理谜题 786: 1 解, 用时 0.0728 秒
# 已处理谜题 787: 1 解, 用时 0.2068 秒
# 已处理谜题 788: 1 解, 用时 0.1123 秒
# 已处理谜题 789: 2 解, 用时 0.1431 秒
# 已处理谜题 79: 2 解, 用时 0.1145 秒
# 已处理谜题 790: 8 解, 用时 0.1724 秒
# 已处理谜题 791: 1 解, 用时 0.1488 秒
# 已处理谜题 792: 47 解, 用时 0.3410 秒
# 已处理谜题 793: 1 解, 用时 0.0741 秒
# 已处理谜题 794: 1 解, 用时 0.0791 秒
# 已处理谜题 795: 2 解, 用时 0.1018 秒
# 已处理谜题 796: 8 解, 用时 0.1197 秒
# 已处理谜题 797: 1 解, 用时 0.0948 秒
# 已处理谜题 798: 1 解, 用时 0.0876 秒
# 已处理谜题 799: 2 解, 用时 0.1203 秒
# 已处理谜题 8: 1 解, 用时 0.0423 秒
# 已处理谜题 80: 5 解, 用时 0.1489 秒
# 已处理谜题 800: 1 解, 用时 0.1296 秒
# 已处理谜题 801: 1 解, 用时 0.1251 秒
# 已处理谜题 802: 1 解, 用时 0.1773 秒
# 已处理谜题 803: 2 解, 用时 0.1674 秒
# 已处理谜题 804: 1 解, 用时 0.0939 秒
# 已处理谜题 805: 1 解, 用时 0.2034 秒
# 已处理谜题 806: 2 解, 用时 0.1739 秒
# 已处理谜题 807: 1 解, 用时 0.0691 秒
# 已处理谜题 808: 4 解, 用时 0.0800 秒
# 已处理谜题 809: 1 解, 用时 0.0432 秒
# 已处理谜题 81: 1 解, 用时 0.1341 秒
# 已处理谜题 810: 1 解, 用时 0.1266 秒
# 已处理谜题 811: 1 解, 用时 0.1732 秒
# 已处理谜题 812: 1 解, 用时 0.1017 秒
# 已处理谜题 813: 1 解, 用时 0.1159 秒
# 已处理谜题 814: 1 解, 用时 0.1825 秒
# 已处理谜题 815: 2 解, 用时 0.1538 秒
# 已处理谜题 816: 1 解, 用时 0.1524 秒
# 已处理谜题 817: 1 解, 用时 0.0911 秒
# 已处理谜题 818: 3 解, 用时 0.1559 秒
# 已处理谜题 819: 2 解, 用时 0.1367 秒
# 已处理谜题 82: 1 解, 用时 0.1230 秒
# 已处理谜题 820: 1 解, 用时 0.0951 秒
# 已处理谜题 821: 1 解, 用时 0.1016 秒
# 已处理谜题 822: 2 解, 用时 0.1212 秒
# 已处理谜题 823: 2 解, 用时 0.2229 秒
# 已处理谜题 824: 1 解, 用时 0.0584 秒
# 已处理谜题 825: 1 解, 用时 0.1780 秒
# 已处理谜题 826: 2 解, 用时 0.1618 秒
# 已处理谜题 827: 2 解, 用时 0.1461 秒
# 已处理谜题 828: 20 解, 用时 0.2146 秒
# 已处理谜题 829: 1 解, 用时 0.1594 秒
# 已处理谜题 83: 1 解, 用时 0.2409 秒
# 已处理谜题 830: 3 解, 用时 0.1660 秒
# 已处理谜题 831: 1 解, 用时 0.1249 秒
# 已处理谜题 832: 1 解, 用时 0.1198 秒
# 已处理谜题 833: 2 解, 用时 0.0443 秒
# 已处理谜题 834: 1 解, 用时 0.0997 秒
# 已处理谜题 835: 1 解, 用时 0.0493 秒
# 已处理谜题 836: 2 解, 用时 0.2101 秒
# 已处理谜题 837: 1 解, 用时 0.1466 秒
# 已处理谜题 838: 2 解, 用时 0.0609 秒
# 已处理谜题 839: 1 解, 用时 0.0989 秒
# 已处理谜题 84: 2 解, 用时 0.0914 秒
# 已处理谜题 840: 1 解, 用时 0.1084 秒
# 已处理谜题 841: 1 解, 用时 0.1946 秒
# 已处理谜题 842: 1 解, 用时 0.1054 秒
# 已处理谜题 843: 2 解, 用时 0.1429 秒
# 已处理谜题 844: 16 解, 用时 0.2419 秒
# 已处理谜题 845: 1 解, 用时 0.1506 秒
# 已处理谜题 846: 223 解, 用时 0.6180 秒
# 已处理谜题 847: 14 解, 用时 0.2102 秒
# 已处理谜题 848: 1 解, 用时 0.0961 秒
# 已处理谜题 849: 1 解, 用时 0.1340 秒
# 已处理谜题 85: 2 解, 用时 0.1471 秒
# 已处理谜题 850: 10 解, 用时 0.1730 秒
# 已处理谜题 851: 1 解, 用时 0.1449 秒
# 已处理谜题 852: 1 解, 用时 0.0925 秒
# 已处理谜题 853: 1 解, 用时 0.1232 秒
# 已处理谜题 854: 12 解, 用时 0.1346 秒
# 已处理谜题 855: 2 解, 用时 0.1382 秒
# 已处理谜题 856: 1 解, 用时 0.1153 秒
# 已处理谜题 857: 1 解, 用时 0.1369 秒
# 已处理谜题 858: 11 解, 用时 0.1574 秒
# 已处理谜题 859: 1 解, 用时 0.2068 秒
# 已处理谜题 86: 1 解, 用时 0.0996 秒
# 已处理谜题 860: 1 解, 用时 0.1809 秒
# 已处理谜题 861: 2 解, 用时 0.0997 秒
# 已处理谜题 862: 1 解, 用时 0.0845 秒
# 已处理谜题 863: 1 解, 用时 0.0495 秒
# 已处理谜题 864: 32 解, 用时 0.0800 秒
# 已处理谜题 865: 1 解, 用时 0.1287 秒
# 已处理谜题 866: 36 解, 用时 0.1494 秒
# 已处理谜题 867: 1 解, 用时 0.0825 秒
# 已处理谜题 868: 49 解, 用时 0.1955 秒
# 已处理谜题 869: 1 解, 用时 0.1691 秒
# 已处理谜题 87: 2 解, 用时 0.1704 秒
# 已处理谜题 870: 2 解, 用时 0.0656 秒
# 已处理谜题 871: 1 解, 用时 0.0588 秒
# 已处理谜题 872: 1 解, 用时 0.1665 秒
# 已处理谜题 873: 1 解, 用时 0.1485 秒
# 已处理谜题 874: 2 解, 用时 0.1211 秒
# 已处理谜题 875: 2 解, 用时 0.1733 秒
# 已处理谜题 876: 6 解, 用时 0.1428 秒
# 已处理谜题 877: 1 解, 用时 0.0567 秒
# 已处理谜题 878: 17 解, 用时 0.1183 秒
# 已处理谜题 879: 3 解, 用时 0.1215 秒
# 已处理谜题 88: 1 解, 用时 0.1632 秒
# 已处理谜题 880: 1 解, 用时 0.1091 秒
# 已处理谜题 881: 1 解, 用时 0.1572 秒
# 已处理谜题 882: 1 解, 用时 0.1167 秒
# 已处理谜题 883: 1 解, 用时 0.1325 秒
# 已处理谜题 884: 2 解, 用时 0.0761 秒
# 已处理谜题 885: 1 解, 用时 0.1250 秒
# 已处理谜题 886: 1 解, 用时 0.1715 秒
# 已处理谜题 887: 1 解, 用时 0.1213 秒
# 已处理谜题 888: 1 解, 用时 0.0623 秒
# 已处理谜题 889: 17 解, 用时 0.2055 秒
# 已处理谜题 89: 2 解, 用时 0.1236 秒
# 已处理谜题 890: 1 解, 用时 0.0796 秒
# 已处理谜题 891: 4 解, 用时 0.0731 秒
# 已处理谜题 892: 38 解, 用时 0.1708 秒
# 已处理谜题 893: 1 解, 用时 0.1153 秒
# 已处理谜题 894: 1 解, 用时 0.0840 秒
# 已处理谜题 895: 1 解, 用时 0.2231 秒
# 已处理谜题 896: 1 解, 用时 0.1275 秒
# 已处理谜题 897: 2 解, 用时 0.1193 秒
# 已处理谜题 898: 1 解, 用时 0.1113 秒
# 已处理谜题 899: 1 解, 用时 0.0707 秒
# 已处理谜题 9: 6 解, 用时 0.1191 秒
# 已处理谜题 90: 1 解, 用时 0.1653 秒
# 已处理谜题 900: 2 解, 用时 0.0998 秒
# 已处理谜题 901: 7 解, 用时 0.1337 秒
# 已处理谜题 902: 8 解, 用时 0.1739 秒
# 已处理谜题 903: 17 解, 用时 0.2105 秒
# 已处理谜题 904: 1 解, 用时 0.0928 秒
# 已处理谜题 905: 1 解, 用时 0.0574 秒
# 已处理谜题 906: 1 解, 用时 0.1286 秒
# 已处理谜题 907: 1 解, 用时 0.1607 秒
# 已处理谜题 908: 1 解, 用时 0.0686 秒
# 已处理谜题 909: 3 解, 用时 0.1217 秒
# 已处理谜题 91: 24 解, 用时 0.1620 秒
# 已处理谜题 910: 3 解, 用时 0.1235 秒
# 已处理谜题 911: 1 解, 用时 0.1046 秒
# 已处理谜题 912: 32 解, 用时 0.1280 秒
# 已处理谜题 913: 1 解, 用时 0.0926 秒
# 已处理谜题 914: 2 解, 用时 0.0910 秒
# 已处理谜题 915: 12 解, 用时 0.1352 秒
# 已处理谜题 916: 1 解, 用时 0.0917 秒
# 已处理谜题 917: 1 解, 用时 0.0869 秒
# 已处理谜题 918: 1 解, 用时 0.0922 秒
# 已处理谜题 919: 1 解, 用时 0.0508 秒
# 已处理谜题 92: 1 解, 用时 0.0554 秒
# 已处理谜题 920: 1 解, 用时 0.0499 秒
# 已处理谜题 921: 1 解, 用时 0.0667 秒
# 已处理谜题 922: 2 解, 用时 0.0892 秒
# 已处理谜题 923: 1 解, 用时 0.1668 秒
# 已处理谜题 924: 1 解, 用时 0.1403 秒
# 已处理谜题 925: 1 解, 用时 0.1243 秒
# 已处理谜题 926: 1 解, 用时 0.0837 秒
# 已处理谜题 927: 2 解, 用时 0.1874 秒
# 已处理谜题 928: 1 解, 用时 0.1230 秒
# 已处理谜题 929: 61 解, 用时 0.3214 秒
# 已处理谜题 93: 1 解, 用时 0.2055 秒
# 已处理谜题 930: 1 解, 用时 0.1944 秒
# 已处理谜题 931: 1 解, 用时 0.1641 秒
# 已处理谜题 932: 2 解, 用时 0.1267 秒
# 已处理谜题 933: 6 解, 用时 0.0887 秒
# 已处理谜题 934: 4 解, 用时 0.1266 秒
# 已处理谜题 935: 4 解, 用时 0.1090 秒
# 已处理谜题 936: 1 解, 用时 0.0669 秒
# 已处理谜题 937: 26 解, 用时 0.1566 秒
# 已处理谜题 938: 1 解, 用时 0.0975 秒
# 已处理谜题 939: 78 解, 用时 0.2362 秒
# 已处理谜题 94: 1 解, 用时 0.1410 秒
# 已处理谜题 940: 12 解, 用时 0.1684 秒
# 已处理谜题 941: 378 解, 用时 0.8060 秒
# 已处理谜题 942: 1 解, 用时 0.0659 秒
# 已处理谜题 943: 3 解, 用时 0.1513 秒
# 已处理谜题 944: 1 解, 用时 0.0783 秒
# 已处理谜题 945: 49 解, 用时 0.1378 秒
# 已处理谜题 946: 1 解, 用时 0.1451 秒
# 已处理谜题 947: 2 解, 用时 0.1041 秒
# 已处理谜题 948: 1 解, 用时 0.1082 秒
# 已处理谜题 949: 1 解, 用时 0.1371 秒
# 已处理谜题 95: 1 解, 用时 0.1231 秒
# 已处理谜题 950: 1 解, 用时 0.0743 秒
# 已处理谜题 951: 11 解, 用时 0.0778 秒
# 已处理谜题 952: 1 解, 用时 0.1469 秒
# 已处理谜题 953: 1 解, 用时 0.1638 秒
# 已处理谜题 954: 2 解, 用时 0.1480 秒
# 已处理谜题 955: 48 解, 用时 0.1990 秒
# 已处理谜题 956: 1 解, 用时 0.0805 秒
# 已处理谜题 957: 532 解, 用时 1.0495 秒
# 已处理谜题 958: 1 解, 用时 0.0923 秒
# 已处理谜题 959: 2 解, 用时 0.0667 秒
# 已处理谜题 96: 1 解, 用时 0.0715 秒
# 已处理谜题 960: 1 解, 用时 0.0915 秒
# 已处理谜题 961: 10 解, 用时 0.0461 秒
# 已处理谜题 962: 6 解, 用时 0.0930 秒
# 已处理谜题 963: 1 解, 用时 0.1097 秒
# 已处理谜题 964: 10 解, 用时 0.0859 秒
# 已处理谜题 965: 1 解, 用时 0.1522 秒
# 已处理谜题 966: 3 解, 用时 0.1042 秒
# 已处理谜题 967: 1 解, 用时 0.0732 秒
# 已处理谜题 968: 1 解, 用时 0.0934 秒
# 已处理谜题 969: 1 解, 用时 0.1056 秒
# 已处理谜题 97: 1 解, 用时 0.1334 秒
# 已处理谜题 970: 1 解, 用时 0.0784 秒
# 已处理谜题 971: 2 解, 用时 0.0880 秒
# 已处理谜题 972: 1 解, 用时 0.1110 秒
# 已处理谜题 973: 2 解, 用时 0.1293 秒
# 已处理谜题 974: 2 解, 用时 0.1123 秒
# 已处理谜题 975: 1 解, 用时 0.1400 秒
# 已处理谜题 976: 4 解, 用时 0.1511 秒
# 已处理谜题 977: 8 解, 用时 0.1742 秒
# 已处理谜题 978: 2 解, 用时 0.0500 秒
# 已处理谜题 979: 34 解, 用时 0.1929 秒
# 已处理谜题 98: 1 解, 用时 0.1161 秒
# 已处理谜题 980: 1 解, 用时 0.1058 秒
# 已处理谜题 981: 1 解, 用时 0.1304 秒
# 已处理谜题 982: 1 解, 用时 0.0378 秒
# 已处理谜题 983: 1 解, 用时 0.1120 秒
# 已处理谜题 984: 5 解, 用时 0.1682 秒
# 已处理谜题 985: 1 解, 用时 0.1021 秒
# 已处理谜题 986: 1 解, 用时 0.0738 秒
# 已处理谜题 987: 4 解, 用时 0.0780 秒
# 已处理谜题 988: 1 解, 用时 0.1149 秒
# 已处理谜题 989: 1 解, 用时 0.1460 秒
# 已处理谜题 99: 5 解, 用时 0.0583 秒
# 已处理谜题 990: 1 解, 用时 0.0535 秒
# 已处理谜题 991: 1 解, 用时 0.1491 秒
# 已处理谜题 992: 1 解, 用时 0.1283 秒
# 已处理谜题 993: 996 解, 用时 2.5800 秒
# 已处理谜题 994: 1 解, 用时 0.0707 秒
# 已处理谜题 995: 6 解, 用时 0.1234 秒
# 已处理谜题 996: 1 解, 用时 0.0846 秒
# 已处理谜题 997: 1 解, 用时 0.1672 秒
# 已处理谜题 998: 2 解, 用时 0.1920 秒
# 已处理谜题 999: 1 解, 用时 0.1813 秒
# 所有结果已保存至 cp_sat_solver_results_seq.csv
