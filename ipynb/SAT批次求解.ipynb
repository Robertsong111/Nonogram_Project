# %%
import os
import json
import time
import pandas as pd
from pysat.solvers import Glucose4
from pysat.formula import CNF, IDPool
import concurrent.futures

# %%
# -------------------------------
# SAT 求解器部分（纯 SAT 模型）
# -------------------------------
def encode_multi_block_nonogram_to_cnf(m, n, row_constraints, col_constraints):
    """
    将“行多段 + 列多段”的 Nonogram 约束编码为 CNF。
    返回 (cnf, varmap)：
      - cnf: pysat.formula.CNF 对象，包含所有子句
      - varmap: 包含:
          varmap['x'][(i,j)]        -> int (变量ID)，表示 x[i][j]
          varmap['rblock'][(i,b,s)] -> int (变量ID)，表示第 i 行的第 b 段从列 s 开始
          varmap['cblock'][(j,b,s)] -> int (变量ID)，表示第 j 列的第 b 段从行 s 开始
    """
    pool = IDPool()
    cnf = CNF()
    varmap = {'x': {}, 'rblock': {}, 'cblock': {}}

    # 1) x[i][j] 变量
    for i in range(m):
        for j in range(n):
            varmap['x'][(i, j)] = pool.id(f"x_{i}_{j}")

    # 2) 行块变量
    for i in range(m):
        blocks = row_constraints[i]
        for b, length_b in enumerate(blocks):
            for start_col in range(n - length_b + 1):
                varmap['rblock'][(i, b, start_col)] = pool.id(f"rB_{i}_{b}_{start_col}")

    # 3) 列块变量
    for j in range(n):
        blocks = col_constraints[j]
        for b, length_b in enumerate(blocks):
            for start_row in range(m - length_b + 1):
                varmap['cblock'][(j, b, start_row)] = pool.id(f"cB_{j}_{b}_{start_row}")

    # -----------------------------
    # 添加行约束子句
    # -----------------------------
    for i in range(m):
        blocks = row_constraints[i]
        if len(blocks) == 0:
            for j in range(n):
                cnf.append([-varmap['x'][(i, j)]])
            continue
        # (A) 每段 exactly one 起始位置
        for b, length_b in enumerate(blocks):
            possible_ids = []
            for start_col in range(n - length_b + 1):
                possible_ids.append(varmap['rblock'][(i, b, start_col)])
            cnf.append(possible_ids)
            for a in range(len(possible_ids)):
                for c in range(a+1, len(possible_ids)):
                    cnf.append([-possible_ids[a], -possible_ids[c]])
        # (B) 相邻段至少隔 1 列空
        for b in range(len(blocks) - 1):
            length_b = blocks[b]
            for start_s in range(n - length_b + 1):
                rblock_s = varmap['rblock'][(i, b, start_s)]
                for start_t in range(n - blocks[b+1] + 1):
                    if start_t < start_s + length_b + 1:
                        rblock_t = varmap['rblock'][(i, b+1, start_t)]
                        cnf.append([-rblock_s, -rblock_t])
        # (C) 覆盖约束：x[i][col] = 1 当且仅当被某个行段覆盖
        for col in range(n):
            cover_ids = []
            for b, length_b in enumerate(blocks):
                for start_s in range(n - length_b + 1):
                    if start_s <= col < start_s + length_b:
                        cover_ids.append(varmap['rblock'][(i, b, start_s)])
            x_id = varmap['x'][(i, col)]
            if not cover_ids:
                cnf.append([-x_id])
            else:
                cnf.append([-x_id] + cover_ids)
                for cid in cover_ids:
                    cnf.append([-cid, x_id])

    # -----------------------------
    # 添加列约束子句
    # -----------------------------
    for j in range(n):
        blocks = col_constraints[j]
        if len(blocks) == 0:
            for i in range(m):
                cnf.append([-varmap['x'][(i, j)]])
            continue
        # (A) 每段 exactly one 起始位置
        for b, length_b in enumerate(blocks):
            possible_ids = []
            for start_i in range(m - length_b + 1):
                possible_ids.append(varmap['cblock'][(j, b, start_i)])
            cnf.append(possible_ids)
            for a in range(len(possible_ids)):
                for c in range(a+1, len(possible_ids)):
                    cnf.append([-possible_ids[a], -possible_ids[c]])
        # (B) 相邻段至少隔 1 行
        for b in range(len(blocks) - 1):
            length_b = blocks[b]
            for start_s in range(m - length_b + 1):
                cblock_s = varmap['cblock'][(j, b, start_s)]
                for start_t in range(m - blocks[b+1] + 1):
                    if start_t < start_s + length_b + 1:
                        cblock_t = varmap['cblock'][(j, b+1, start_t)]
                        cnf.append([-cblock_s, -cblock_t])
        # (C) 覆盖约束：x[i][j] 与列块变量之间的关系
        for i in range(m):
            cover_ids = []
            for b, length_b in enumerate(blocks):
                for start_s in range(m - length_b + 1):
                    if start_s <= i < start_s + length_b:
                        cover_ids.append(varmap['cblock'][(j, b, start_s)])
            x_id = varmap['x'][(i, j)]
            if not cover_ids:
                cnf.append([-x_id])
            else:
                cnf.append([-x_id] + cover_ids)
                for cid in cover_ids:
                    cnf.append([-cid, x_id])
    return cnf, varmap

# %%
def decode_solution(m, n, varmap, model_solution):
    sol_matrix = []
    for i in range(m):
        rowvals = []
        for j in range(n):
            x_id = varmap['x'][(i, j)]
            rowvals.append(1 if model_solution[x_id] else 0)
        sol_matrix.append(rowvals)
    return sol_matrix

# %%
def add_blocking_clause(cnf, varmap, solution_matrix):
    clause = []
    m = len(solution_matrix)
    n = len(solution_matrix[0])
    for i in range(m):
        for j in range(n):
            x_id = varmap['x'][(i, j)]
            if solution_matrix[i][j] == 1:
                clause.append(-x_id)
            else:
                clause.append(x_id)
    cnf.append(clause)

# %%
def solve_all_solutions_pure_sat(m, n, row_constraints, col_constraints):
    cnf, varmap = encode_multi_block_nonogram_to_cnf(m, n, row_constraints, col_constraints)
    solutions = []
    while True:
        solver = Glucose4()
        for clause in cnf.clauses:
            solver.add_clause(clause)
        ok = solver.solve()
        if not ok:
            solver.delete()
            break
        model = solver.get_model()
        assignment = {}
        for lit in model:
            if lit > 0:
                assignment[lit] = True
            else:
                assignment[-lit] = False
        sol_matrix = decode_solution(m, n, varmap, assignment)
        solutions.append(sol_matrix)
        add_blocking_clause(cnf, varmap, sol_matrix)
        solver.delete()
    return solutions

# %%
# -------------------------------
# 批量处理及记录求解结果
# -------------------------------
def process_puzzle_file(file_path):
    """读取 JSON 文件，返回 puzzle 数据字典"""
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

# %%
def solve_puzzle(puzzle):
    """
    对一个 puzzle 求解，返回求解时间和解的数量。
    puzzle 中应包含 row_hints 或 row_constraints 以及 col_hints 或 col_constraints。
    """
    # 获取行提示和列提示，支持不同的键名
    row_hints = puzzle.get("row_hints", puzzle.get("row_constraints"))
    col_hints = puzzle.get("col_hints", puzzle.get("col_constraints"))
    m = len(row_hints)
    n = len(col_hints)
    start = time.time()
    solutions = solve_all_solutions_pure_sat(m, n, row_hints, col_hints)
    end = time.time()
    return end - start, len(solutions)

# %%
def process_and_solve(file_path):
    """
    读取谜题文件，对谜题求解，返回一个记录字典。
    """
    puzzle = process_puzzle_file(file_path)
    pid = puzzle.get("id", os.path.basename(file_path))
    label = puzzle.get("label", None)
    row_hints = puzzle.get("row_hints", puzzle.get("row_constraints"))
    col_hints = puzzle.get("col_hints", puzzle.get("col_constraints"))
    
    solve_time, num_sol = solve_puzzle(puzzle)
    # 返回一个字典记录
    return {
        "puzzle_id": pid,
        "label": label,
        "row_hints": str(row_hints),
        "col_hints": str(col_hints),
        "num_solutions": num_sol,
        "solving_time_sec": solve_time
    }

# %%
def main():
    folder = "./mnist_nonograms"  # 你的谜题文件夹
    records = []
    for filename in os.listdir(folder):
        if filename.lower().endswith(".json"):
            file_path = os.path.join(folder, filename)
            puzzle = process_puzzle_file(file_path)
            pid = puzzle.get("id", filename)
            label = puzzle.get("label", None)
            row_hints = puzzle.get("row_hints", puzzle.get("row_constraints"))
            col_hints = puzzle.get("col_hints", puzzle.get("col_constraints"))
            print(f"Processing puzzle {pid} ...")
            solve_time, num_sol = solve_puzzle(puzzle)
            print(f"Puzzle {pid}: {num_sol} solution(s) in {solve_time:.4f} sec")
            records.append({
                "puzzle_id": pid,
                "label": label,
                "row_hints": str(row_hints),
                "col_hints": str(col_hints),
                "num_solutions": num_sol,
                "solving_time_sec": solve_time
            })
    df = pd.DataFrame(records)
    output_file = "sat_solver_results.csv"
    df.to_csv(output_file, index=False)
    print(f"Results saved in {output_file}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing puzzle 0 ...
# Puzzle 0: 1 solution(s) in 0.0685 sec
# Processing puzzle 1 ...
# Puzzle 1: 1 solution(s) in 0.0589 sec
# Processing puzzle 10 ...
# Puzzle 10: 1 solution(s) in 0.0657 sec
# Processing puzzle 100 ...
# Puzzle 100: 1 solution(s) in 0.0272 sec
# Processing puzzle 101 ...
# Puzzle 101: 1 solution(s) in 0.0401 sec
# Processing puzzle 102 ...
# Puzzle 102: 1 solution(s) in 0.0152 sec
# Processing puzzle 103 ...
# Puzzle 103: 1 solution(s) in 0.0346 sec
# Processing puzzle 104 ...
# Puzzle 104: 1 solution(s) in 0.0150 sec
# Processing puzzle 105 ...
# Puzzle 105: 1 solution(s) in 0.0203 sec
# Processing puzzle 106 ...
# Puzzle 106: 1 solution(s) in 0.0721 sec
# Processing puzzle 107 ...
# Puzzle 107: 1 solution(s) in 0.0411 sec
# Processing puzzle 108 ...
# Puzzle 108: 1 solution(s) in 0.0826 sec
# Processing puzzle 109 ...
# Puzzle 109: 1 solution(s) in 0.0554 sec
# Processing puzzle 11 ...
# Puzzle 11: 2 solution(s) in 0.0786 sec
# Processing puzzle 110 ...
# Puzzle 110: 1 solution(s) in 0.0472 sec
# Processing puzzle 111 ...
# Puzzle 111: 1 solution(s) in 0.0741 sec
# Processing puzzle 112 ...
# Puzzle 112: 1 solution(s) in 0.0185 sec
# Processing puzzle 113 ...
# Puzzle 113: 1 solution(s) in 0.0273 sec
# Processing puzzle 114 ...
# Puzzle 114: 1 solution(s) in 0.1212 sec
# Processing puzzle 115 ...
# Puzzle 115: 2 solution(s) in 0.0695 sec
# Processing puzzle 116 ...
# Puzzle 116: 1 solution(s) in 0.0710 sec
# Processing puzzle 117 ...
# Puzzle 117: 2 solution(s) in 0.1190 sec
# Processing puzzle 118 ...
# Puzzle 118: 1 solution(s) in 0.1358 sec
# Processing puzzle 119 ...
# Puzzle 119: 1 solution(s) in 0.0896 sec
# Processing puzzle 12 ...
# Puzzle 12: 3 solution(s) in 0.0948 sec
# Processing puzzle 120 ...
# Puzzle 120: 1 solution(s) in 0.0568 sec
# Processing puzzle 121 ...
# Puzzle 121: 1 solution(s) in 0.1486 sec
# Processing puzzle 122 ...
# Puzzle 122: 1 solution(s) in 0.0518 sec
# Processing puzzle 123 ...
# Puzzle 123: 1 solution(s) in 0.0593 sec
# Processing puzzle 124 ...
# Puzzle 124: 1 solution(s) in 0.0242 sec
# Processing puzzle 125 ...
# Puzzle 125: 1 solution(s) in 0.0596 sec
# Processing puzzle 126 ...
# Puzzle 126: 1 solution(s) in 0.0794 sec
# Processing puzzle 127 ...
# Puzzle 127: 1 solution(s) in 0.0759 sec
# Processing puzzle 128 ...
# Puzzle 128: 1 solution(s) in 0.0223 sec
# Processing puzzle 129 ...
# Puzzle 129: 1 solution(s) in 0.0638 sec
# Processing puzzle 13 ...
# Puzzle 13: 1 solution(s) in 0.0746 sec
# Processing puzzle 130 ...
# Puzzle 130: 2 solution(s) in 0.1127 sec
# Processing puzzle 131 ...
# Puzzle 131: 1 solution(s) in 0.0684 sec
# Processing puzzle 132 ...
# Puzzle 132: 1 solution(s) in 0.0269 sec
# Processing puzzle 133 ...
# Puzzle 133: 1 solution(s) in 0.0593 sec
# Processing puzzle 134 ...
# Puzzle 134: 1 solution(s) in 0.0979 sec
# Processing puzzle 135 ...
# Puzzle 135: 1 solution(s) in 0.0983 sec
# Processing puzzle 136 ...
# Puzzle 136: 1 solution(s) in 0.0567 sec
# Processing puzzle 137 ...
# Puzzle 137: 2 solution(s) in 0.0603 sec
# Processing puzzle 138 ...
# Puzzle 138: 1 solution(s) in 0.0976 sec
# Processing puzzle 139 ...
# Puzzle 139: 1 solution(s) in 0.0850 sec
# Processing puzzle 14 ...
# Puzzle 14: 1 solution(s) in 0.0692 sec
# Processing puzzle 140 ...
# Puzzle 140: 1 solution(s) in 0.0568 sec
# Processing puzzle 141 ...
# Puzzle 141: 1 solution(s) in 0.0681 sec
# Processing puzzle 142 ...
# Puzzle 142: 1 solution(s) in 0.0529 sec
# Processing puzzle 143 ...
# Puzzle 143: 1 solution(s) in 0.0562 sec
# Processing puzzle 144 ...
# Puzzle 144: 8 solution(s) in 0.5640 sec
# Processing puzzle 145 ...
# Puzzle 145: 6 solution(s) in 0.1078 sec
# Processing puzzle 146 ...
# Puzzle 146: 3 solution(s) in 0.1404 sec
# Processing puzzle 147 ...
# Puzzle 147: 1 solution(s) in 0.0436 sec
# Processing puzzle 148 ...
# Puzzle 148: 1 solution(s) in 0.0926 sec
# Processing puzzle 149 ...
# Puzzle 149: 1 solution(s) in 0.0809 sec
# Processing puzzle 15 ...
# Puzzle 15: 1 solution(s) in 0.0522 sec
# Processing puzzle 150 ...
# Puzzle 150: 1 solution(s) in 0.0704 sec
# Processing puzzle 151 ...
# Puzzle 151: 1 solution(s) in 0.1353 sec
# Processing puzzle 152 ...
# Puzzle 152: 1 solution(s) in 0.0218 sec
# Processing puzzle 153 ...
# Puzzle 153: 2 solution(s) in 0.0802 sec
# Processing puzzle 154 ...
# Puzzle 154: 1 solution(s) in 0.0601 sec
# Processing puzzle 155 ...
# Puzzle 155: 1 solution(s) in 0.0614 sec
# Processing puzzle 156 ...
# Puzzle 156: 1 solution(s) in 0.1148 sec
# Processing puzzle 157 ...
# Puzzle 157: 1 solution(s) in 0.0747 sec
# Processing puzzle 158 ...
# Puzzle 158: 2 solution(s) in 0.0885 sec
# Processing puzzle 159 ...
# Puzzle 159: 1 solution(s) in 0.0820 sec
# Processing puzzle 16 ...
# Puzzle 16: 1 solution(s) in 0.1258 sec
# Processing puzzle 160 ...
# Puzzle 160: 2 solution(s) in 0.0985 sec
# Processing puzzle 161 ...
# Puzzle 161: 1 solution(s) in 0.0576 sec
# Processing puzzle 162 ...
# Puzzle 162: 1 solution(s) in 0.0410 sec
# Processing puzzle 163 ...
# Puzzle 163: 3 solution(s) in 0.1580 sec
# Processing puzzle 164 ...
# Puzzle 164: 1 solution(s) in 0.0510 sec
# Processing puzzle 165 ...
# Puzzle 165: 1 solution(s) in 0.0595 sec
# Processing puzzle 166 ...
# Puzzle 166: 1 solution(s) in 0.0622 sec
# Processing puzzle 167 ...
# Puzzle 167: 1 solution(s) in 0.1122 sec
# Processing puzzle 168 ...
# Puzzle 168: 1 solution(s) in 0.0387 sec
# Processing puzzle 169 ...
# Puzzle 169: 1 solution(s) in 0.0414 sec
# Processing puzzle 17 ...
# Puzzle 17: 1 solution(s) in 0.0500 sec
# Processing puzzle 170 ...
# Puzzle 170: 2 solution(s) in 0.0570 sec
# Processing puzzle 171 ...
# Puzzle 171: 1 solution(s) in 0.1152 sec
# Processing puzzle 172 ...
# Puzzle 172: 1 solution(s) in 0.0486 sec
# Processing puzzle 173 ...
# Puzzle 173: 1 solution(s) in 0.0357 sec
# Processing puzzle 174 ...
# Puzzle 174: 1 solution(s) in 0.0304 sec
# Processing puzzle 175 ...
# Puzzle 175: 1 solution(s) in 0.0554 sec
# Processing puzzle 176 ...
# Puzzle 176: 1 solution(s) in 0.0353 sec
# Processing puzzle 177 ...
# Puzzle 177: 1 solution(s) in 0.0734 sec
# Processing puzzle 178 ...
# Puzzle 178: 2 solution(s) in 0.1183 sec
# Processing puzzle 179 ...
# Puzzle 179: 1 solution(s) in 0.0804 sec
# Processing puzzle 18 ...
# Puzzle 18: 41 solution(s) in 0.9882 sec
# Processing puzzle 180 ...
# Puzzle 180: 1 solution(s) in 0.0647 sec
# Processing puzzle 181 ...
# Puzzle 181: 1 solution(s) in 0.0690 sec
# Processing puzzle 182 ...
# Puzzle 182: 1 solution(s) in 0.0506 sec
# Processing puzzle 183 ...
# Puzzle 183: 1 solution(s) in 0.0464 sec
# Processing puzzle 184 ...
# Puzzle 184: 1 solution(s) in 0.0225 sec
# Processing puzzle 185 ...
# Puzzle 185: 1 solution(s) in 0.0818 sec
# Processing puzzle 186 ...
# Puzzle 186: 1 solution(s) in 0.0443 sec
# Processing puzzle 187 ...
# Puzzle 187: 1 solution(s) in 0.0554 sec
# Processing puzzle 188 ...
# Puzzle 188: 2 solution(s) in 0.0960 sec
# Processing puzzle 189 ...
# Puzzle 189: 1 solution(s) in 0.0872 sec
# Processing puzzle 19 ...
# Puzzle 19: 2 solution(s) in 0.0783 sec
# Processing puzzle 190 ...
# Puzzle 190: 1 solution(s) in 0.0582 sec
# Processing puzzle 191 ...
# Puzzle 191: 1 solution(s) in 0.0669 sec
# Processing puzzle 192 ...
# Puzzle 192: 1 solution(s) in 0.1008 sec
# Processing puzzle 193 ...
# Puzzle 193: 2 solution(s) in 0.1229 sec
# Processing puzzle 194 ...
# Puzzle 194: 2 solution(s) in 0.1064 sec
# Processing puzzle 195 ...
# Puzzle 195: 1 solution(s) in 0.0774 sec
# Processing puzzle 196 ...
# Puzzle 196: 1 solution(s) in 0.0624 sec
# Processing puzzle 197 ...
# Puzzle 197: 1 solution(s) in 0.1672 sec
# Processing puzzle 198 ...
# Puzzle 198: 1 solution(s) in 0.0957 sec
# Processing puzzle 199 ...
# Puzzle 199: 1 solution(s) in 0.1011 sec
# Processing puzzle 2 ...
# Puzzle 2: 1 solution(s) in 0.0747 sec
# Processing puzzle 20 ...
# Puzzle 20: 1 solution(s) in 0.0664 sec
# Processing puzzle 200 ...
# Puzzle 200: 1 solution(s) in 0.0623 sec
# Processing puzzle 201 ...
# Puzzle 201: 1 solution(s) in 0.0323 sec
# Processing puzzle 202 ...
# Puzzle 202: 1 solution(s) in 0.0820 sec
# Processing puzzle 203 ...
# Puzzle 203: 1 solution(s) in 0.1287 sec
# Processing puzzle 204 ...
# Puzzle 204: 1 solution(s) in 0.0830 sec
# Processing puzzle 205 ...
# Puzzle 205: 1 solution(s) in 0.0933 sec
# Processing puzzle 206 ...
# Puzzle 206: 1 solution(s) in 0.1413 sec
# Processing puzzle 207 ...
# Puzzle 207: 1 solution(s) in 0.0652 sec
# Processing puzzle 208 ...
# Puzzle 208: 1 solution(s) in 0.0250 sec
# Processing puzzle 209 ...
# Puzzle 209: 1 solution(s) in 0.0965 sec
# Processing puzzle 21 ...
# Puzzle 21: 1 solution(s) in 0.1237 sec
# Processing puzzle 210 ...
# Puzzle 210: 520 solution(s) in 40.7223 sec
# Processing puzzle 211 ...
# Puzzle 211: 1 solution(s) in 0.0370 sec
# Processing puzzle 212 ...
# Puzzle 212: 1 solution(s) in 0.0518 sec
# Processing puzzle 213 ...
# Puzzle 213: 1 solution(s) in 0.1282 sec
# Processing puzzle 214 ...
# Puzzle 214: 1 solution(s) in 0.0552 sec
# Processing puzzle 215 ...
# Puzzle 215: 1 solution(s) in 0.0720 sec
# Processing puzzle 216 ...
# Puzzle 216: 4 solution(s) in 0.2182 sec
# Processing puzzle 217 ...
# Puzzle 217: 1 solution(s) in 0.1296 sec
# Processing puzzle 218 ...
# Puzzle 218: 1 solution(s) in 0.1067 sec
# Processing puzzle 219 ...
# Puzzle 219: 2 solution(s) in 0.1435 sec
# Processing puzzle 22 ...
# Puzzle 22: 4 solution(s) in 0.1597 sec
# Processing puzzle 220 ...
# Puzzle 220: 1 solution(s) in 0.1570 sec
# Processing puzzle 221 ...
# Puzzle 221: 1 solution(s) in 0.0854 sec
# Processing puzzle 222 ...
# Puzzle 222: 1 solution(s) in 0.0807 sec
# Processing puzzle 223 ...
# Puzzle 223: 1 solution(s) in 0.0775 sec
# Processing puzzle 224 ...
# Puzzle 224: 2 solution(s) in 0.1605 sec
# Processing puzzle 225 ...
# Puzzle 225: 1 solution(s) in 0.0917 sec
# Processing puzzle 226 ...
# Puzzle 226: 1 solution(s) in 0.0677 sec
# Processing puzzle 227 ...
# Puzzle 227: 1 solution(s) in 0.0765 sec
# Processing puzzle 228 ...
# Puzzle 228: 2 solution(s) in 0.1285 sec
# Processing puzzle 229 ...
# Puzzle 229: 1 solution(s) in 0.1542 sec
# Processing puzzle 23 ...
# Puzzle 23: 1 solution(s) in 0.0472 sec
# Processing puzzle 230 ...
# Puzzle 230: 1 solution(s) in 0.0952 sec
# Processing puzzle 231 ...
# Puzzle 231: 1 solution(s) in 0.0299 sec
# Processing puzzle 232 ...
# Puzzle 232: 1 solution(s) in 0.0925 sec
# Processing puzzle 233 ...
# Puzzle 233: 1 solution(s) in 0.1547 sec
# Processing puzzle 234 ...
# Puzzle 234: 1 solution(s) in 0.1553 sec
# Processing puzzle 235 ...
# Puzzle 235: 1 solution(s) in 0.0926 sec
# Processing puzzle 236 ...
# Puzzle 236: 1 solution(s) in 0.0839 sec
# Processing puzzle 237 ...
# Puzzle 237: 1 solution(s) in 0.0673 sec
# Processing puzzle 238 ...
# Puzzle 238: 1 solution(s) in 0.2285 sec
# Processing puzzle 239 ...
# Puzzle 239: 1 solution(s) in 0.1438 sec
# Processing puzzle 24 ...
# Puzzle 24: 1 solution(s) in 0.1183 sec
# Processing puzzle 240 ...
# Puzzle 240: 1 solution(s) in 0.1116 sec
# Processing puzzle 241 ...
# Puzzle 241: 1 solution(s) in 0.1894 sec
# Processing puzzle 242 ...
# Puzzle 242: 1 solution(s) in 0.2097 sec
# Processing puzzle 243 ...
# Puzzle 243: 1 solution(s) in 0.1294 sec
# Processing puzzle 244 ...
# Puzzle 244: 2 solution(s) in 0.2291 sec
# Processing puzzle 245 ...
# Puzzle 245: 1 solution(s) in 0.2376 sec
# Processing puzzle 246 ...
# Puzzle 246: 3 solution(s) in 0.3739 sec
# Processing puzzle 247 ...
# Puzzle 247: 1 solution(s) in 0.1499 sec
# Processing puzzle 248 ...
# Puzzle 248: 1 solution(s) in 0.0625 sec
# Processing puzzle 249 ...
# Puzzle 249: 1 solution(s) in 0.3304 sec
# Processing puzzle 25 ...
# Puzzle 25: 1 solution(s) in 0.1527 sec
# Processing puzzle 250 ...
# Puzzle 250: 1 solution(s) in 0.1667 sec
# Processing puzzle 251 ...
# Puzzle 251: 1 solution(s) in 0.1112 sec
# Processing puzzle 252 ...
# Puzzle 252: 1 solution(s) in 0.1436 sec
# Processing puzzle 253 ...
# Puzzle 253: 1 solution(s) in 0.3092 sec
# Processing puzzle 254 ...
# Puzzle 254: 1 solution(s) in 0.2697 sec
# Processing puzzle 255 ...
# Puzzle 255: 1 solution(s) in 0.1751 sec
# Processing puzzle 256 ...
# Puzzle 256: 1 solution(s) in 0.1615 sec
# Processing puzzle 257 ...
# Puzzle 257: 1 solution(s) in 0.1706 sec
# Processing puzzle 258 ...
# Puzzle 258: 1 solution(s) in 0.1454 sec
# Processing puzzle 259 ...
# Puzzle 259: 2 solution(s) in 0.2555 sec
# Processing puzzle 26 ...
# Puzzle 26: 1 solution(s) in 0.1083 sec
# Processing puzzle 260 ...
# Puzzle 260: 4 solution(s) in 0.3942 sec
# Processing puzzle 261 ...
# Puzzle 261: 1 solution(s) in 0.2356 sec
# Processing puzzle 262 ...
# Puzzle 262: 1 solution(s) in 0.1624 sec
# Processing puzzle 263 ...
# Puzzle 263: 1 solution(s) in 0.1251 sec
# Processing puzzle 264 ...
# Puzzle 264: 1 solution(s) in 0.1640 sec
# Processing puzzle 265 ...
# Puzzle 265: 1 solution(s) in 0.2111 sec
# Processing puzzle 266 ...
# Puzzle 266: 1 solution(s) in 0.1176 sec
# Processing puzzle 267 ...
# Puzzle 267: 1 solution(s) in 0.0887 sec
# Processing puzzle 268 ...
# Puzzle 268: 1 solution(s) in 0.0904 sec
# Processing puzzle 269 ...
# Puzzle 269: 1 solution(s) in 0.0556 sec
# Processing puzzle 27 ...
# Puzzle 27: 1 solution(s) in 0.1914 sec
# Processing puzzle 270 ...
# Puzzle 270: 1 solution(s) in 0.0406 sec
# Processing puzzle 271 ...
# Puzzle 271: 1 solution(s) in 0.0773 sec
# Processing puzzle 272 ...
# Puzzle 272: 1 solution(s) in 0.1301 sec
# Processing puzzle 273 ...
# Puzzle 273: 1 solution(s) in 0.1094 sec
# Processing puzzle 274 ...
# Puzzle 274: 1 solution(s) in 0.1256 sec
# Processing puzzle 275 ...
# Puzzle 275: 1 solution(s) in 0.0752 sec
# Processing puzzle 276 ...
# Puzzle 276: 1 solution(s) in 0.0373 sec
# Processing puzzle 277 ...
# Puzzle 277: 1 solution(s) in 0.1214 sec
# Processing puzzle 278 ...
# Puzzle 278: 1 solution(s) in 0.0779 sec
# Processing puzzle 279 ...
# Puzzle 279: 1 solution(s) in 0.1565 sec
# Processing puzzle 28 ...
# Puzzle 28: 1 solution(s) in 0.1010 sec
# Processing puzzle 280 ...
# Puzzle 280: 1 solution(s) in 0.1195 sec
# Processing puzzle 281 ...
# Puzzle 281: 1 solution(s) in 0.1003 sec
# Processing puzzle 282 ...
# Puzzle 282: 1 solution(s) in 0.0785 sec
# Processing puzzle 283 ...
# Puzzle 283: 1 solution(s) in 0.1516 sec
# Processing puzzle 284 ...
# Puzzle 284: 2 solution(s) in 0.1695 sec
# Processing puzzle 285 ...
# Puzzle 285: 1 solution(s) in 0.0801 sec
# Processing puzzle 286 ...
# Puzzle 286: 1 solution(s) in 0.0531 sec
# Processing puzzle 287 ...
# Puzzle 287: 1 solution(s) in 0.1379 sec
# Processing puzzle 288 ...
# Puzzle 288: 1 solution(s) in 0.0512 sec
# Processing puzzle 289 ...
# Puzzle 289: 1 solution(s) in 0.0564 sec
# Processing puzzle 29 ...
# Puzzle 29: 1 solution(s) in 0.0653 sec
# Processing puzzle 290 ...
# Puzzle 290: 1 solution(s) in 0.0360 sec
# Processing puzzle 291 ...
# Puzzle 291: 1 solution(s) in 0.0772 sec
# Processing puzzle 292 ...
# Puzzle 292: 1 solution(s) in 0.1147 sec
# Processing puzzle 293 ...
# Puzzle 293: 1 solution(s) in 0.0858 sec
# Processing puzzle 294 ...
# Puzzle 294: 1 solution(s) in 0.0763 sec
# Processing puzzle 295 ...
# Puzzle 295: 1 solution(s) in 0.0913 sec
# Processing puzzle 296 ...
# Puzzle 296: 1 solution(s) in 0.1411 sec
# Processing puzzle 297 ...
# Puzzle 297: 2 solution(s) in 0.0982 sec
# Processing puzzle 298 ...
# Puzzle 298: 1 solution(s) in 0.0822 sec
# Processing puzzle 299 ...
# Puzzle 299: 1 solution(s) in 0.1146 sec
# Processing puzzle 3 ...
# Puzzle 3: 1 solution(s) in 0.0396 sec
# Processing puzzle 30 ...
# Puzzle 30: 1 solution(s) in 0.1448 sec
# Processing puzzle 300 ...
# Puzzle 300: 1 solution(s) in 0.0990 sec
# Processing puzzle 301 ...
# Puzzle 301: 1 solution(s) in 0.0737 sec
# Processing puzzle 302 ...
# Puzzle 302: 1 solution(s) in 0.0943 sec
# Processing puzzle 303 ...
# Puzzle 303: 1 solution(s) in 0.1113 sec
# Processing puzzle 304 ...
# Puzzle 304: 1 solution(s) in 0.1216 sec
# Processing puzzle 305 ...
# Puzzle 305: 1 solution(s) in 0.0647 sec
# Processing puzzle 306 ...
# Puzzle 306: 1 solution(s) in 0.1187 sec
# Processing puzzle 307 ...
# Puzzle 307: 1 solution(s) in 0.0588 sec
# Processing puzzle 308 ...
# Puzzle 308: 1 solution(s) in 0.1500 sec
# Processing puzzle 309 ...
# Puzzle 309: 1 solution(s) in 0.0382 sec
# Processing puzzle 31 ...
# Puzzle 31: 1 solution(s) in 0.0665 sec
# Processing puzzle 310 ...
# Puzzle 310: 1 solution(s) in 0.0353 sec
# Processing puzzle 311 ...
# Puzzle 311: 1 solution(s) in 0.0739 sec
# Processing puzzle 312 ...
# Puzzle 312: 1 solution(s) in 0.1656 sec
# Processing puzzle 313 ...
# Puzzle 313: 1 solution(s) in 0.0529 sec
# Processing puzzle 314 ...
# Puzzle 314: 1 solution(s) in 0.1125 sec
# Processing puzzle 315 ...
# Puzzle 315: 1 solution(s) in 0.0467 sec
# Processing puzzle 316 ...
# Puzzle 316: 4 solution(s) in 0.1371 sec
# Processing puzzle 317 ...
# Puzzle 317: 1 solution(s) in 0.1795 sec
# Processing puzzle 318 ...
# Puzzle 318: 1 solution(s) in 0.1154 sec
# Processing puzzle 319 ...
# Puzzle 319: 1 solution(s) in 0.0448 sec
# Processing puzzle 32 ...
# Puzzle 32: 2 solution(s) in 0.1545 sec
# Processing puzzle 320 ...
# Puzzle 320: 1 solution(s) in 0.1157 sec
# Processing puzzle 321 ...
# Puzzle 321: 2 solution(s) in 0.0590 sec
# Processing puzzle 322 ...
# Puzzle 322: 1 solution(s) in 0.0816 sec
# Processing puzzle 323 ...
# Puzzle 323: 1 solution(s) in 0.0676 sec
# Processing puzzle 324 ...
# Puzzle 324: 1 solution(s) in 0.1214 sec
# Processing puzzle 325 ...
# Puzzle 325: 1 solution(s) in 0.0524 sec
# Processing puzzle 326 ...
# Puzzle 326: 1 solution(s) in 0.0614 sec
# Processing puzzle 327 ...
# Puzzle 327: 1 solution(s) in 0.0579 sec
# Processing puzzle 328 ...
# Puzzle 328: 1 solution(s) in 0.0530 sec
# Processing puzzle 329 ...
# Puzzle 329: 1 solution(s) in 0.1071 sec
# Processing puzzle 33 ...
# Puzzle 33: 1 solution(s) in 0.0557 sec
# Processing puzzle 330 ...
# Puzzle 330: 1 solution(s) in 0.0396 sec
# Processing puzzle 331 ...
# Puzzle 331: 1 solution(s) in 0.0390 sec
# Processing puzzle 332 ...
# Puzzle 332: 1 solution(s) in 0.0505 sec
# Processing puzzle 333 ...
# Puzzle 333: 1 solution(s) in 0.1561 sec
# Processing puzzle 334 ...
# Puzzle 334: 1 solution(s) in 0.0870 sec
# Processing puzzle 335 ...
# Puzzle 335: 1 solution(s) in 0.0848 sec
# Processing puzzle 336 ...
# Puzzle 336: 1 solution(s) in 0.0560 sec
# Processing puzzle 337 ...
# Puzzle 337: 1 solution(s) in 0.1094 sec
# Processing puzzle 338 ...
# Puzzle 338: 1 solution(s) in 0.0640 sec
# Processing puzzle 339 ...
# Puzzle 339: 1 solution(s) in 0.0980 sec
# Processing puzzle 34 ...
# Puzzle 34: 1 solution(s) in 0.0835 sec
# Processing puzzle 340 ...
# Puzzle 340: 1 solution(s) in 0.1018 sec
# Processing puzzle 341 ...
# Puzzle 341: 1 solution(s) in 0.0669 sec
# Processing puzzle 342 ...
# Puzzle 342: 1 solution(s) in 0.0482 sec
# Processing puzzle 343 ...
# Puzzle 343: 1 solution(s) in 0.0805 sec
# Processing puzzle 344 ...
# Puzzle 344: 1 solution(s) in 0.1424 sec
# Processing puzzle 345 ...
# Puzzle 345: 1 solution(s) in 0.0371 sec
# Processing puzzle 346 ...
# Puzzle 346: 1 solution(s) in 0.0711 sec
# Processing puzzle 347 ...
# Puzzle 347: 1 solution(s) in 0.0950 sec
# Processing puzzle 348 ...
# Puzzle 348: 1 solution(s) in 0.0708 sec
# Processing puzzle 349 ...
# Puzzle 349: 1 solution(s) in 0.1290 sec
# Processing puzzle 35 ...
# Puzzle 35: 1 solution(s) in 0.0554 sec
# Processing puzzle 350 ...
# Puzzle 350: 1 solution(s) in 0.0599 sec
# Processing puzzle 351 ...
# Puzzle 351: 1 solution(s) in 0.0391 sec
# Processing puzzle 352 ...
# Puzzle 352: 2 solution(s) in 0.1966 sec
# Processing puzzle 353 ...
# Puzzle 353: 1 solution(s) in 0.0707 sec
# Processing puzzle 354 ...
# Puzzle 354: 1 solution(s) in 0.0724 sec
# Processing puzzle 355 ...
# Puzzle 355: 1 solution(s) in 0.0323 sec
# Processing puzzle 356 ...
# Puzzle 356: 1 solution(s) in 0.0910 sec
# Processing puzzle 357 ...
# Puzzle 357: 1 solution(s) in 0.0282 sec
# Processing puzzle 358 ...
# Puzzle 358: 1 solution(s) in 0.0219 sec
# Processing puzzle 359 ...
# Puzzle 359: 1 solution(s) in 0.1449 sec
# Processing puzzle 36 ...
# Puzzle 36: 1 solution(s) in 0.0801 sec
# Processing puzzle 360 ...
# Puzzle 360: 1 solution(s) in 0.0775 sec
# Processing puzzle 361 ...
# Puzzle 361: 1 solution(s) in 0.0583 sec
# Processing puzzle 362 ...
# Puzzle 362: 1 solution(s) in 0.0430 sec
# Processing puzzle 363 ...
# Puzzle 363: 1 solution(s) in 0.1056 sec
# Processing puzzle 364 ...
# Puzzle 364: 1 solution(s) in 0.1082 sec
# Processing puzzle 365 ...
# Puzzle 365: 1 solution(s) in 0.0724 sec
# Processing puzzle 366 ...
# Puzzle 366: 1 solution(s) in 0.0240 sec
# Processing puzzle 367 ...
# Puzzle 367: 1 solution(s) in 0.0772 sec
# Processing puzzle 368 ...
# Puzzle 368: 1 solution(s) in 0.1123 sec
# Processing puzzle 369 ...
# Puzzle 369: 1 solution(s) in 0.0652 sec
# Processing puzzle 37 ...
# Puzzle 37: 1 solution(s) in 0.0642 sec
# Processing puzzle 370 ...
# Puzzle 370: 2 solution(s) in 0.0735 sec
# Processing puzzle 371 ...
# Puzzle 371: 1 solution(s) in 0.0489 sec
# Processing puzzle 372 ...
# Puzzle 372: 1 solution(s) in 0.0771 sec
# Processing puzzle 373 ...
# Puzzle 373: 1 solution(s) in 0.0445 sec
# Processing puzzle 374 ...
# Puzzle 374: 1 solution(s) in 0.0457 sec
# Processing puzzle 375 ...
# Puzzle 375: 1 solution(s) in 0.0864 sec
# Processing puzzle 376 ...
# Puzzle 376: 1 solution(s) in 0.0482 sec
# Processing puzzle 377 ...
# Puzzle 377: 1 solution(s) in 0.1221 sec
# Processing puzzle 378 ...
# Puzzle 378: 1 solution(s) in 0.0689 sec
# Processing puzzle 379 ...
# Puzzle 379: 1 solution(s) in 0.0617 sec
# Processing puzzle 38 ...
# Puzzle 38: 1 solution(s) in 0.0545 sec
# Processing puzzle 380 ...
# Puzzle 380: 1 solution(s) in 0.0761 sec
# Processing puzzle 381 ...
# Puzzle 381: 1 solution(s) in 0.1934 sec
# Processing puzzle 382 ...
# Puzzle 382: 1 solution(s) in 0.0423 sec
# Processing puzzle 383 ...
# Puzzle 383: 1 solution(s) in 0.0799 sec
# Processing puzzle 384 ...
# Puzzle 384: 1 solution(s) in 0.0833 sec
# Processing puzzle 385 ...
# Puzzle 385: 1 solution(s) in 0.1465 sec
# Processing puzzle 386 ...
# Puzzle 386: 2 solution(s) in 0.1856 sec
# Processing puzzle 387 ...
# Puzzle 387: 1 solution(s) in 0.1047 sec
# Processing puzzle 388 ...
# Puzzle 388: 2 solution(s) in 0.0844 sec
# Processing puzzle 389 ...
# Puzzle 389: 1 solution(s) in 0.0681 sec
# Processing puzzle 39 ...
# Puzzle 39: 1 solution(s) in 0.1168 sec
# Processing puzzle 390 ...
# Puzzle 390: 1 solution(s) in 0.0929 sec
# Processing puzzle 391 ...
# Puzzle 391: 1 solution(s) in 0.0973 sec
# Processing puzzle 392 ...
# Puzzle 392: 1 solution(s) in 0.1490 sec
# Processing puzzle 393 ...
# Puzzle 393: 1 solution(s) in 0.1188 sec
# Processing puzzle 394 ...
# Puzzle 394: 1 solution(s) in 0.0233 sec
# Processing puzzle 395 ...
# Puzzle 395: 1 solution(s) in 0.0887 sec
# Processing puzzle 396 ...
# Puzzle 396: 1 solution(s) in 0.1083 sec
# Processing puzzle 397 ...
# Puzzle 397: 1 solution(s) in 0.0938 sec
# Processing puzzle 398 ...
# Puzzle 398: 1 solution(s) in 0.0353 sec
# Processing puzzle 399 ...
# Puzzle 399: 1 solution(s) in 0.0809 sec
# Processing puzzle 4 ...
# Puzzle 4: 1 solution(s) in 0.0662 sec
# Processing puzzle 40 ...
# Puzzle 40: 1 solution(s) in 0.0423 sec
# Processing puzzle 400 ...
# Puzzle 400: 1 solution(s) in 0.0963 sec
# Processing puzzle 401 ...
# Puzzle 401: 1 solution(s) in 0.1120 sec
# Processing puzzle 402 ...
# Puzzle 402: 1 solution(s) in 0.0628 sec
# Processing puzzle 403 ...
# Puzzle 403: 1 solution(s) in 0.0875 sec
# Processing puzzle 404 ...
# Puzzle 404: 1 solution(s) in 0.1298 sec
# Processing puzzle 405 ...
# Puzzle 405: 2 solution(s) in 0.2109 sec
# Processing puzzle 406 ...
# Puzzle 406: 1 solution(s) in 0.0489 sec
# Processing puzzle 407 ...
# Puzzle 407: 1 solution(s) in 0.0914 sec
# Processing puzzle 408 ...
# Puzzle 408: 1 solution(s) in 0.0277 sec
# Processing puzzle 409 ...
# Puzzle 409: 1 solution(s) in 0.0980 sec
# Processing puzzle 41 ...
# Puzzle 41: 1 solution(s) in 0.1493 sec
# Processing puzzle 410 ...
# Puzzle 410: 1 solution(s) in 0.0948 sec
# Processing puzzle 411 ...
# Puzzle 411: 1 solution(s) in 0.0575 sec
# Processing puzzle 412 ...
# Puzzle 412: 3 solution(s) in 0.0867 sec
# Processing puzzle 413 ...
# Puzzle 413: 1 solution(s) in 0.0684 sec
# Processing puzzle 414 ...
# Puzzle 414: 1 solution(s) in 0.0430 sec
# Processing puzzle 415 ...
# Puzzle 415: 1 solution(s) in 0.1031 sec
# Processing puzzle 416 ...
# Puzzle 416: 1 solution(s) in 0.0190 sec
# Processing puzzle 417 ...
# Puzzle 417: 2 solution(s) in 0.0701 sec
# Processing puzzle 418 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[17], line 13, in main()
#      11 col_hints = puzzle.get("col_hints", puzzle.get("col_constraints"))
#      12 print(f"Processing puzzle {pid} ...")
# ---> 13 solve_time, num_sol = solve_puzzle(puzzle)
#      14 print(f"Puzzle {pid}: {num_sol} solution(s) in {solve_time:.4f} sec")
#      15 records.append({
#      16     "puzzle_id": pid,
#      17     "label": label,
#    (...)
#      21     "solving_time_sec": solve_time
#      22 })
#
# Cell In[13], line 12, in solve_puzzle(puzzle)
#      10 n = len(col_hints)
#      11 start = time.time()
# ---> 12 solutions = solve_all_solutions_pure_sat(m, n, row_hints, col_hints)
#      13 end = time.time()
#      14 return end - start, len(solutions)
#
# Cell In[9], line 12, in solve_all_solutions_pure_sat(m, n, row_constraints, col_constraints)
#      10     solver.delete()
#      11     break
# ---> 12 model = solver.get_model()
#      13 assignment = {}
#      14 for lit in model:
#
# File D:\anaconda\Lib\site-packages\pysat\solvers.py:4025, in Glucose4.get_model(self)
#    4022     if self.glucose:
#    4023         return self.status
# -> 4025 def get_model(self):
#    4026     """
#    4027         Get a model if the formula was previously satisfied.
#    4028     """
#    4030     if self.glucose and self.status == True:
#
# KeyboardInterrupt:
